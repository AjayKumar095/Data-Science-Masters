# %% [markdown]
# <h1><center>Constructor</center></h1>

# %% [markdown]
# <h3>1. What is a constructor in Python? Explain its purpose and usage.</h3>
# <p><b>Answer.</b></p>
# <p>
# In Python, a constructor is a special method within a class that is automatically called when an object of that class is created. The purpose of a constructor is to initialize the attributes (or properties) of the object. In other words, it sets up the initial state of the object. In Python, the constructor method is named __init__. When you create an instance of a class, the __init__ method is automatically invoked</p>

# %% [markdown]
# <h3>2. Differentiate between a parameterless constructor and a parameterized constructor in Python.</h3>
# <p><b>Answer.</b></p>
# <p>Constructors can be categorized into two types: parameterless constructors and parameterized constructors.</p>
# <ul>
#     <li>
#         <strong>Parameterless Constructor:</strong>
#         <ul>
#             <li>
#                 <strong>Definition:</strong> A parameterless constructor is a constructor that does not take any parameters, except for the mandatory <code>self</code> parameter, which represents the instance of the class.
#             </li>
#             <li>
#                 <strong>Purpose:</strong> It is used when the initialization of the object doesn't require any external information or input values.
#             </li>
#         </ul>
#     </li>
#     <li>
#         <strong>Parameterized Constructor:</strong>
#         <ul>
#             <li>
#                 <strong>Definition:</strong> A parameterized constructor is a constructor that takes parameters, in addition to the mandatory <code>self</code> parameter, to initialize the attributes of the object with specific values.
#             </li>
#             <li>
#                 <strong>Purpose:</strong> It is used when the initialization of the object requires external information or input values.
#             </li>
#         </ul>
#     </li>
# </ul>

# %%
""""3. How do you define a constructor in a Python class? Provide an example."""

"""Answer
       A constructor is defined within a class using a special method named __init__"""
       
# Exapmle

class Exapmle :  # Declaring a python class
    
    def __init__(self): # Declaring a constructor within  python class.
        pass

# %% [markdown]
# <h3>4. Explain the `__init__` method in Python and its role in constructors.</h3>
# <p><b>Answer.</b></p>
# <p>In Python, the __init__ method is a special method that plays a crucial role in constructors. It is automatically called when an object is created from a class and is used to initialize the attributes (or properties) of the object. The name __init__ stands for "initialize."</p>
# <ul>
#     <li>
#         <p><strong>Initialization:</strong> The primary purpose of the <code>__init__</code> method is to initialize the attributes of the object with default values or values provided during object creation.</p>
#     </li>
#     <li>
#         <p><strong>Automatic Invocation:</strong> When you create an instance of a class, Python automatically calls the <code>__init__</code> method of that class, allowing you to perform any necessary setup or initialization.</p>
#     </li>
#     <li>
#         <p><strong>Parameters:</strong> The <code>__init__</code> method takes parameters, with the first parameter conventionally named <code>self</code>. This parameter refers to the instance of the class and is used to access and modify attributes within the class.</p>
#     </li>
#     <li>
#         <p><strong>Attribute Assignment:</strong> Inside the <code>__init__</code> method, you can assign values to the attributes of the object using the <code>self</code> reference. These assigned values can come from parameters passed to the constructor during object creation.</p>
#     </li>
# </ul>

# %%
"""5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an
example of creating an object of this class."""

# Declaring the class person

class person:
    
    def __init__(self, name, age): #creating a constructor
        self.name=name
        self.age=age
    
    def person_info(self):  # Method to display the person information.
        return f"My name is {self.name} and I'm {self.age} years old."
    
# Creating class instance and passing different perimeters.        
person1=person("Mohan",34)
person2=person("Sohan", 23)

# Printing the person information.
print(person1.person_info())
print(person2.person_info())

# %%
"""6. How can you call a constructor explicitly in Python? Give an example."""

"""Answer
     In Python, a constructor is typically called automatically when an object is created. 
     However, if you need to call a constructor explicitly, you can do so using the class name."""
     
# declaring a class
class MyClass:
    def __init__(self, param1, param2): #creating a constructor
        self.attribute1 = param1
        self.attribute2 = param2

# Explicitly calling the constructor
explicit_object = MyClass.__new__(MyClass)
MyClass.__init__(explicit_object, "value1", "value2")

# Accessing the attributes of the explicitly created object
print(explicit_object.attribute1)  # Output: explicit_value1
print(explicit_object.attribute2)  # Output: explicit_value2

# %%
"""7. What is the significance of the `self` parameter in Python constructors? Explain with an example."""

"""Answer
   The significance of the `self` parameter in Python constructors is that it allows you to access
   and modify the attributes and methods of the object within the class.
   The use of self is a convention in Python,
   and you can choose any name for this parameter, but self is widely accepted and recommended."""
   
# Exapmle
# Declaring the class person

class person:
    
    def __init__(self, name, age): #creating a constructor
        self.name=name
        self.age=age
    
    def person_info(self):  # Method to display the person information.
        return f"My name is {self.name} and I'm {self.age} years old."
    
# Creating class instance and passing different perimeters.        
person1=person("Mohan",34)
person2=person("Sohan", 23)

# Printing the person information.
print(person1.person_info())
print(person2.person_info())

# %%
"""8. Discuss the concept of default constructors in Python. When are they used?"""

"""Answer
     In Python, a default constructor is a constructor that doesn't take any parameters beyond the mandatory self parameter. """
     
class MyClass:
    def __init__(self):
        # This is the default constructor
        self.default_attribute = "Default Value"

# Creating an instance of MyClass with the default constructor
my_object = MyClass()

# Printing the result
print(my_object.default_attribute)

# %%
"""9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height`
attributes. Provide a method to calculate the area of the rectangle."""

# Exapmle
# Declaring the class person

class rectangle:
    
    def __init__(self, width, height): #creating a constructor
        self.width=width
        self.height=height
    
    def area(self):  # Method to display the person information.
        return self.width*self.height
    
# Creating class instance and passing different perimeters.        
field=rectangle(5,30)

# Printing the area of rectangle.
print(f"Area of rectangle is {field.area()} m.sq")

# %%
"""10. How can you have multiple constructors in a Python class? Explain with an example."""

"""Answer
    While Python doesn't support method overloading in the traditional sense,
    you can achieve similar functionality by providing default values for some parameters or
    by using class methods to create instances."""
    
# Exapmle by using default values.
class MyClass:
    def __init__(self, attribute1=None, attribute2=None):
        # Constructor with default values
        self.attribute1 = attribute1
        self.attribute2 = attribute2

# Creating an instance with default values
obj_default = MyClass()

# Creating an instance with specific values
obj_specific = MyClass("value1", "value2")

# Accessing attributes
print(obj_default.attribute1, obj_default.attribute2)  
print(obj_specific.attribute1, obj_specific.attribute2)

# %% [markdown]
# <h3>11. What is method overloading, and how is it related to constructors in Python?</h3>
# <p><b>Answer.</b></p>
# <p><strong>Method Overloading in Python:</strong> Method overloading in Python refers to the ability to define multiple methods within a class with the same name but with different parameters. While Python doesn't support traditional method overloading, you can achieve a form of it through default parameter values or variable-length argument lists.</p>
#
# <p><strong>Related to Constructors:</strong> Constructors in Python can make use of default parameter values or variable-length argument lists to simulate method overloading. This provides flexibility in creating instances of a class with different sets of parameters.</p>
#
# <ul>
#     <li><strong>Default Parameter Values for Constructors:</strong>
#         <ul>
#             <li>You can provide default values for parameters in a constructor to simulate method overloading based on the number of parameters.</li>
#             <li>Example:
#                 <pre>
#                 <code>
# class MyClass:
#     def __init__(self, attribute1=None, attribute2=None):
#         # Constructor with default values
#         self.attribute1 = attribute1
#         self.attribute2 = attribute2
#                 </code>
#                 </pre>
#             </li>
#         </ul>
#     </li>
#
# <li><strong>Variable-Length Argument Lists:</strong>
#         <ul>
#             <li>You can use variable-length argument lists (`*args` and `**kwargs`) in a constructor to handle a variable number of parameters.</li>
#             <li>Example:
#                 <pre>
#                 <code>
# class MyClass:
#     def __init__(self, *args, **kwargs):
#         # Constructor with variable-length argument lists
#         self.attributes = args
#         self.keyword_attributes = kwargs
#                 </code>
#                 </pre>
#             </li>
#         </ul>
#     </li>
# </ul>

# %%
"""12. Explain the use of the `super()` function in Python constructors. Provide an example."""

"""Answer.
    In Python, the super() function is used in constructors to call the constructor of the parent (or superclass) class.
    It is particularly useful in situations where you have overridden the constructor in a subclass"""
    
# Exapmle
class ParentClass:
    def __init__(self, parent_attribute):
        print("Inside ParentClass constructor")
        self.parent_attribute = parent_attribute

class ChildClass(ParentClass):
    def __init__(self, parent_attribute, child_attribute):
        # Calling the constructor of the parent class using super()
        super().__init__(parent_attribute)
        
        # Initializing attributes specific to the child class
        print("Inside ChildClass constructor")
        self.child_attribute = child_attribute

# Creating an instance of ChildClass
child_object = ChildClass("Parent Value", "Child Value")

# Accessing attributes of both parent and child classes
print("Parent Attribute:", child_object.parent_attribute)
print("Child Attribute:", child_object.child_attribute)

# %%
"""13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year`
attributes. Provide a method to display book details."""

# declaring a class book
class Book:
    
    def __init__(self, title,author, published_year): # Declaring constructor.
        self.title=title
        self.author=author
        self.published_year=published_year
        
    def display_book_details(self):  # method to display book details.
        return f"Title: {self.title} \nAuthor: {self.author} \nPublished Year: {self.published_year}"    


book_data=Book("Atomic Habits","James Clear", "16 October 2018")    
print(book_data.display_book_details())

# %% [markdown]
# <h3>14. Discuss the differences between constructors and regular methods in Python classes.</h3>
# <p><b>Answer.</b></p>
# <table border="1">
#     <tr>
#         <th>Aspect</th>
#         <th>Constructors</th>
#         <th>Regular Methods</th>
#     </tr>
#     <tr>
#         <td><strong>Definition</strong></td>
#         <td>A special method within a class used for initializing object attributes. In Python, the constructor is named <code>__init__</code>.</td>
#         <td>Methods defined within a class for performing specific operations or actions on class attributes. They are not specifically for object initialization.</td>
#     </tr>
#     <tr>
#         <td><strong>Invocation</strong></td>
#         <td>Automatically called when an object is created from the class.</td>
#         <td>Manually called on an object instance to perform a specific action or operation.</td>
#     </tr>
#     <tr>
#         <td><strong>Parameters</strong></td>
#         <td>Includes the mandatory <code>self</code> parameter and any additional parameters needed for object initialization.</td>
#         <td>Includes the mandatory <code>self</code> parameter and any additional parameters needed for the method to operate.</td>
#     </tr>
#     <tr>
#         <td><strong>Purpose</strong></td>
#         <td>To initialize the attributes of an object and set up its initial state.</td>
#         <td>To perform specific operations or actions on the attributes of an object.</td>
#     </tr>
#     <tr>
#         <td><strong>Usage</strong></td>
#         <td>Automatically invoked when an object is created, typically used for attribute initialization.</td>
#         <td>Manually called when needed to perform a specific action on the object's attributes.</td>
#     </tr>
# </table>

# %% [markdown]
# <h3>15. Explain the role of the `self` parameter in instance variable initialization within a constructor.</h3>
# <p><B>Answer.</B></p>
# <p><strong>In Python, the self parameter in a constructor plays a crucial role in instance variable initialization. The self parameter is a reference to the instance of the class, and it allows you to access and modify the attributes (instance variables) of that particular object.</strong></p>
#
# <p><strong>Here's an explanation of the role of the self parameter in instance variable initialization within a constructor:</strong></p>
#
# <ul>
#     <li><strong>Instance Variable Initialization:</strong>
#         <ul>
#             <li>The primary purpose of a constructor is to initialize the attributes (instance variables) of an object when it is created.</li>
#             <li>Instance variables represent the state of an object, and they can have different values for different instances of the same class.</li>
#         </ul>
#     </li>
#     <li><strong>Using self for Attribute Access:</strong>
#         <ul>
#             <li>Within the constructor, the self parameter serves as a reference to the current instance of the class.</li>
#             <li>By using self, you can access and modify instance variables specific to the object being created.</li>
#         </ul>
#     </li>
# </ul>

# %%
"""16. How do you prevent a class from having multiple instances by using constructors in Python? Provide an
example."""

"""Answer.
    you can prevent a class from having multiple instances by implementing a design pattern called the Singleton Pattern.
    The Singleton Pattern ensures that a class has only one instance and provides a global point of access to that instance.
    This is typically achieved by controlling the instantiation process within the class itself."""
 
# Exapmle
class SingletonClass:
    _instance = None  # Class variable to store the single instance

    def __new__(cls):
        # Create a new instance only if it doesn't exist
        if cls._instance is None:
            cls._instance = super(SingletonClass, cls).__new__(cls)
        return cls._instance

    def __init__(self):
        # Initialization logic (will be executed only once)
        if not hasattr(self, '_initialized'):
            self._initialized = True
            # Additional initialization code can go here

# Creating instances of SingletonClass
singleton_instance1 = SingletonClass()
singleton_instance2 = SingletonClass()

# Checking if both instances refer to the same object
print(singleton_instance1 is singleton_instance2)  # Output: True

# %%
"""17. Create a Python class called `Student` with a constructor that takes a list of subjects as a parameter and
initializes the `subjects` attribute."""

class Student:
    def __init__(self, subject_list):
        # Constructor to initialize the subjects attribute
        self.subjects = subject_list


# Creating a Student instance with a list of subjects
student_instance = Student(["Math", "Physics", "English", "History"])

# Accessing the subjects attribute
print("Subjects:", student_instance.subjects)

# %% [markdown]
# <h3>18. What is the purpose of the `__del__` method in Python classes, and how does it relate to constructors?</h3>
# <p><b>Answer.</b></p>
# <ul>
#     <li>
#         <strong>Purpose of __del__ Method:</strong>
#         <ul>
#             <li>The primary purpose of the __del__ method is to define the actions that should be taken when an object is no longer needed.</li>
#             <li>It allows you to perform cleanup tasks, such as releasing resources, closing files, or freeing memory associated with the object.</li>
#         </ul>
#     </li>
#     <li>
#         <strong>Invocation of __del__ Method:</strong>
#         <ul>
#             <li>The __del__ method is automatically called by the Python interpreter when an object is garbage-collected or explicitly deleted using the del keyword.</li>
#             <li>It is the counterpart to the __init__ method, which is the constructor responsible for initializing the object.</li>
#         </ul>
#     </li>
#     <li>
#         <strong>Relation to Constructors:</strong>
#         <ul>
#             <li>While the __init__ method is called when an object is created and initialized, the __del__ method is called when the object is being destroyed.</li>
#             <li>Together, they represent the initialization and cleanup phases of an object's lifecycle.</li>
#         </ul>
#     </li>
# </ul>
# <p><b>Example</b></p>
# <ul>
#     <li>
#         <strong>Example Code:</strong>
#         <pre>
#             <code>
# class MyClass:
#     def __init__(self):
#         print("Initializing object")
#
#     def __del__(self):
#         print("Deleting object")
#
#
# obj = MyClass()
# del obj
#             </code>
#         </pre>
#     </li>
# </ul>

# %%
"""19. Explain the use of constructor chaining in Python. Provide a practical example."""

"""Answer.
    
Constructor chaining in Python refers to the concept of one constructor calling
another constructor within the same class or in its parent class.
This allows for reusing the initialization logic and avoiding code duplication."""

# Example
class ParentClass:
    def __init__(self, parent_attribute):
        print("Inside ParentClass constructor")
        self.parent_attribute = parent_attribute

class ChildClass(ParentClass):
    def __init__(self, parent_attribute, child_attribute):
        # Call the constructor of the parent class using super()
        super().__init__(parent_attribute)

        print("Inside ChildClass constructor")
        self.child_attribute = child_attribute


# Creating childclass instance 
child_object = ChildClass("Parent Value", "Child Value")

# printing result
print("Parent Attribute:", child_object.parent_attribute)
print("Child Attribute:", child_object.child_attribute)

# %%
"""20. Create a Python class called `Car` with a default constructor that initializes the `make` and `model`
attributes. Provide a method to display car information."""

# Declaring a class car.

class Car:
    
    def __init__(self,make, model): # Constructor to initialize the subjects attribute
        self.make=make
        self.model=model
    
    def display_car(self): # method to display car 
        return f"Make : {self.make} \nModel : {self.model}"


# Class object
car=Car("Honda",2023)
print(car.display_car())

# %% [markdown]
# <h1><center>Inheritance</center></h1>

# %% [markdown]
# <h3>1. What is inheritance in Python? Explain its significance in object-oriented programming.</h3>
# <p><b>Answer.</b></p>
# <p>
# In Python, inheritance is a fundamental concept in object-oriented programming (OOP) that allows a class (called the child or derived class) to inherit attributes and behaviors from another class (called the parent or base class). This enables the child class to reuse and extend the functionality of the parent class.
#
# Inheritance promotes code reusability and helps in organizing and structuring code in a more logical and modular way. The parent class serves as a blueprint, defining common attributes and methods that can be shared by multiple related classes. </p>

# %% [markdown]
# <h3>2. Differentiate between single inheritance and multiple inheritance in Python. Provide examples for each.</h3>
# <p>Answer.</p>
#    <h3>Python Inheritance Comparison</h3>
#
#  <table>
#         <tr>
#             <th>Aspect</th>
#             <th>Single Inheritance</th>
#             <th>Multiple Inheritance</th>
#         </tr>
#         <tr>
#             <td>Number of Parent Classes</td>
#             <td>One</td>
#             <td>More than one</td>
#         </tr>
#         <tr>
#             <td>Child Class</td>
#             <td>Derived from a single base class</td>
#             <td>Derived from multiple base classes</td>
#         </tr>
#         <tr>
#             <td>Flexibility</td>
#             <td>Simpler model, easier to understand</td>
#             <td>More flexibility but can be complex</td>
#         </tr>
#         <tr>
#             <td>Example</td>
#             <td>
#                 <pre>
# class Animal:
#     def speak(self):
#         pass
#
# class Dog(Animal):
#     def bark(self):
#         return "Woof!"
#                 </pre>
#             </td>
#             <td>
#                 <pre>
# class Flyable:
#     def fly(self):
#         return "I can fly!"
#
# class Swimmable:
#     def swim(self):
#         return "I can swim!"
#
# class Amphibian(Flyable, Swimmable):
#     pass
#                 </pre>
#             </td>
#         </tr>
#     </table>

# %%
"""3. Create a Python class called `Vehicle` with attributes `color` and `speed`. Then, create a child class called
`Car` that inherits from `Vehicle` and adds a `brand` attribute. Provide an example of creating a `Car` object."""

class Vehicle:
    def __init__(self, color, speed):
        self.color = color
        self.speed = speed

class Car(Vehicle):
    def __init__(self, color, speed, brand):
       
        super().__init__(color, speed)
        self.brand = brand


my_car = Car(color="Blue", speed=60, brand="Toyota")

print(f"Color: {my_car.color}")
print(f"Speed: {my_car.speed} km/h")
print(f"Brand: {my_car.brand}")

# %%
"""4. Explain the concept of method overriding in inheritance. Provide a practical example."""

"""Answer
        Method overriding is a concept in object-oriented programming that allow a subclass
        to provide a specific implementation for a method that is already defined in its superclass."""

# Example
class Animal:
    def make_sound(self):
        return "Generic animal sound"

class Dog(Animal):
    def make_sound(self):
        return "Woof! Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow! Meow!"

# Creating instances 
dog_instance = Dog()
cat_instance = Cat()

# Calling methods
print(dog_instance.make_sound())  
print(cat_instance.make_sound())

# %%
"""5. How can you access the methods and attributes of a parent class from a child class in Python? Give an
example."""

"""Answer
In Python, you can access the methods and attributes of a parent class from a child class using the super() function."""

# Example
class Animal:
    def __init__(self, species):
        self.species = species

    def make_sound(self):
        return "Generic animal sound"

class Dog(Animal):
    def __init__(self, species, breed):
    
        super().__init__(species)
        self.breed = breed

    def make_sound(self):

        parent_sound = super().make_sound()
        return f"{parent_sound} - Woof! Woof!"

# Creating an instance 
my_dog = Dog(species="Canine", breed="Golden Retriever")

# Accessing attributes of the parent class 
print(f"Species: {my_dog.species}")
print(f"Breed: {my_dog.breed}")

# Calling the method 
print(my_dog.make_sound())

# %%
"""6. Discuss the use of the `super()` function in Python inheritance. When and why is it used? Provide an
example."""

"""Answer
        
The super() function in Python is used in the context of inheritance
to access methods and attributes of a parent or superclass within a subclass."""

# Example
class Animal:
    def __init__(self, species):
        self.species = species

    def make_sound(self):
        return "Generic animal sound"

class Dog(Animal):
    def __init__(self, species, breed):
     
        super().__init__(species)
        self.breed = breed

    def make_sound(self):
      
        parent_sound = super().make_sound()
        return f"{parent_sound} - Woof! Woof!"

# Creating an instance
my_dog = Dog(species="Canine", breed="Golden Retriever")

# Accessing attributes 
print(f"Species: {my_dog.species}")

# Calling the method of the parent class 
print(my_dog.make_sound())

# %%
"""7. Create a Python class called `Animal` with a method `speak()`. Then, create child classes `Dog` and `Cat` that inherit from `Animal` and override the `speak()` method. Provide an example of using these classes."""

# Example
class Animal:
    def make_sound(self):
        return "Generic animal sound"

class Dog(Animal):
    def make_sound(self):
        return "Woof! Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow! Meow!"

# Creating instances 
dog_instance = Dog()
cat_instance = Cat()

# Calling methods
print(dog_instance.make_sound())  
print(cat_instance.make_sound())

# %%
"""8. Explain the role of the `isinstance()` function in Python and how it relates to inheritance."""
"""Answer
        The isinstance() function in Python is used to check if an object belongs to a specified class or a tuple of classes.
        It returns True if the object is an instance of any of the specified classes and False otherwise."""

# Example
class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def bark(self):
        return "Woof! Woof!"

class Cat(Animal):
    def meow(self):
        return "Meow! Meow!"

# Creating instances 
animal_instance = Animal()
dog_instance = Dog()
cat_instance = Cat()

# Using isinstance() 
print(isinstance(animal_instance, Animal))  
print(isinstance(dog_instance, Animal))     
print(isinstance(cat_instance, Animal))    

print(isinstance(dog_instance, Dog))     
print(isinstance(cat_instance, Dog))      

print(isinstance(animal_instance, (Dog, Cat)))

# %%
"""9. What is the purpose of the `issubclass()` function in Python? Provide an example."""

"""Answer.
        The issubclass() function in Python is used to check whether a class is a subclass of another class.
        It returns True if the first class is a subclass of the second class, and False otherwise. """
# Example
class Animal:
    pass

class Mammal(Animal):
    pass

class Dog(Mammal):
    pass

# Using issubclass() to check inheritance relationships
print(issubclass(Mammal, Animal))  
print(issubclass(Dog, Mammal))     
print(issubclass(Dog, Animal))     

# Non-subclass relationship
print(issubclass(Animal, Mammal))  
print(issubclass(Mammal, Dog))

# %% [markdown]
# <h2>10. Discuss the concept of constructor inheritance in Python. How are constructors inherited in child classes?</h2>
# <p><b>Answer.</b></p>
# <h3>Constructor Inheritance in Python</h3>
#
# <ul>
#         <li><strong>Inheriting the Constructor:</strong>
#             <ul>
#                 <li>If a child class does not define its own constructor, it automatically inherits the constructor of its parent class.</li>
#                 <li>Inherited means that the child class can use the constructor of the parent class to initialize the attributes of the child class.</li>
#             </ul>
#         </li>
#         <li><strong>Defining a Constructor in the Child Class:</strong>
#             <ul>
#                 <li>If a child class defines its own constructor, it can still choose to explicitly call the constructor of the parent class using <code>super().__init__(...)</code>.</li>
#                 <li>This allows the child class to add additional initialization steps while still benefiting from the parent class's initialization.</li>
#             </ul>
#         </li>
#     </ul>
#
# <p>Example:</p>
#     <pre>
# <code>
# class Animal:
#     def __init__(self, species):
#         self.species = species
#         print("Animal constructor called")
# </code>
# <code>
# class Dog(Animal):
#     def __init__(self, species, breed):
#         super().__init__(species)
#         self.breed = breed
#         print("Dog constructor called")
# </code>
# <code>
# my_dog = Dog(species="Canine", breed="Golden Retriever")
#     </code>
# </pre>

# %%
"""11. Create a Python class called `Shape` with a method `area()` that calculates the area of a shape. Then, create child classes `Circle` and `Rectangle` that inherit from `Shape` and implement the `area()` method
accordingly. Provide an example."""

import math

class Shape:
    def area(self):
        pass  

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Passing values
circle_instance = Circle(radius=5)
rectangle_instance = Rectangle(length=4, width=6)

# printing the areas
print(f"Area of the circle: {circle_instance.area():.2f}")
print(f"Area of the rectangle: {rectangle_instance.area()}")

# %%
"""12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an
example using the `abc` module."""

"""Answer

Abstract Base Classes (ABCs) in Python provide a way to define a common interface for a group of related classes,
enforcing that all the derived classes implement certain methods.
ABCs can be used to define abstract methods that must be overridden in the subclasses. """

# Example.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius**2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


circle_instance = Circle(radius=5)
rectangle_instance = Rectangle(length=4, width=6)

# Calculating and printing the areas
print(f"Area of the circle: {circle_instance.area():.2f}")
print(f"Area of the rectangle: {rectangle_instance.area()}")

# %% [markdown]
# <h2>13. How can you prevent a child class from modifying certain attributes or methods inherited from a parent
# class in Python?</h2>
# <p><b>Answer.</b></p>
#  <h4>Access Control in Python Classes</h4>
#
# <ul>
#         <li><strong>Private Attributes and Methods:</strong>
#             <ul>
#                 <li>Prefix the attribute or method name with a double underscore (`__`) in the parent class.</li>
#                 <li>This makes the attribute or method private to the class, and it can only be accessed within the class itself.</li>
#             </ul>
#         </li>
#         <li><strong>Protected Attributes and Methods:</strong>
#             <ul>
#                 <li>Prefix the attribute or method name with a single underscore (`_`) in the parent class.</li>
#                 <li>This convention indicates that the attribute or method is protected, and it should not be accessed or modified outside the class.</li>
#             </ul>
#         </li>
#         <li><strong>Use Getters and Setters:</strong>
#             <ul>
#                 <li>Instead of exposing attributes directly, provide getter and setter methods in the parent class.</li>
#                 <li>This allows you to control how attributes are accessed and modified.</li>
#             </ul>
#         </li>
#     </ul>

# %%
"""14. Create a Python class called `Employee` with attributes `name` and `salary`. Then, create a child class
`Manager` that inherits from `Employee` and adds an attribute `department`. Provide an example."""

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

class Manager(Employee):
    def __init__(self, name, salary, department):
       
        super().__init__(name, salary)
        self.department = department


employee_instance = Employee(name="John Doe", salary=50000)
manager_instance = Manager(name="Jane Smith", salary=80000, department="Sales")

print(f"Employee Name: {employee_instance.name}")
print(f"Employee Salary: ${employee_instance.salary}")

# Accessing attributes of the Manager instance
print(f"Manager Name: {manager_instance.name}")
print(f"Manager Salary: ${manager_instance.salary}")
print(f"Manager Department: {manager_instance.department}")

# %% [markdown]
# <h2>15. Discuss the concept of method overloading in Python inheritance. How does it differ from method
# overriding?</h2>
# <p><b>Answer.</b></p>
# <h4>Method Overloading and Method Overriding in Python Inheritance</h4>
#
# <p><strong>Method Overloading:</strong></p>
#     <ul>
#         <li>In Python, method overloading is a concept where a class can define multiple methods with the same name but different parameter lists.</li>
#         <li>The methods must have different signatures, which means different types or a different number of parameters.</li>
#         <li>Python does not support traditional method overloading as seen in some other languages, but it allows for a form of overloading using default values or variable-length argument lists.</li>
#         <li>Method overloading is determined at the time of the function call based on the number or type of arguments provided.</li>
#     </ul>
#
# <p><strong>Method Overriding:</strong></p>
#     <ul>
#         <li>Method overriding is a concept in Python inheritance where a subclass provides a specific implementation for a method that is already defined in its superclass.</li>
#         <li>The overriding method in the subclass must have the same name, return type, and parameters as the method in the superclass.</li>
#         <li>Method overriding is a way to customize or extend the behavior of the inherited method while maintaining a common interface.</li>
#         <li>It allows for polymorphism, where different classes can be treated as instances of the same class while exhibiting behavior specific to their individual types.</li>
#     </ul>

# %% [markdown]
# <h2>16. Explain the purpose of the `__init__()` method in Python inheritance and how it is utilized in child classes.</h2>
# <p><b>Answer.</b></p>
#    <h4>The Purpose of the <code>__init__()</code> Method in Python Inheritance</h4>
#
# <p><strong>In the Parent Class (Superclass):</strong></p>
#     <ul>
#         <li>The <code>__init__()</code> method in the parent class is a special constructor method.</li>
#         <li>It is automatically called when an object of the class is created.</li>
#         <li>The primary purpose is to initialize attributes that are common to all instances of the class.</li>
#         <li>It may take parameters representing the initial values of those attributes.</li>
#         <li>It sets the initial state of the object based on the provided parameters.</li>
#     </ul>
#
# <p><strong>In the Child Class (Subclass):</strong></p>
#     <ul>
#         <li>When a child class inherits from a parent class, it can have its own <code>__init__()</code> method.</li>
#         <li>The child class's <code>__init__()</code> method may include additional parameters specific to the child class.</li>
#         <li>It can call the parent class's <code>__init__()</code> method using <code>super().__init__(...)</code> to initialize attributes inherited from the parent.</li>
#         <li>This ensures proper initialization of the object with attributes from both the parent and child classes.</li>
#     </ul>

# %%
"""17. Create a Python class called `Bird` with a method `fly()`. Then, create child classes `Eagle` and `Sparrow` that inherit from `Bird` and implement the `fly()` method differently. Provide an example of using these
classes."""

class Bird:
    def fly(self):
        return "I can fly!"

class Eagle(Bird):
    def fly(self):
        return "Soaring high in the sky like an eagle!"

class Sparrow(Bird):
    def fly(self):
        return "Flitting through the air like a sparrow!"


bird_instance = Bird()
eagle_instance = Eagle()
sparrow_instance = Sparrow()

# Calling the fly() methods
print(bird_instance.fly())    
print(eagle_instance.fly())   
print(sparrow_instance.fly())

# %% [markdown]
# <h2>18. What is the "diamond problem" in multiple inheritance, and how does Python address it?</h2>
# <p><b>Answer.</b></p>
# <h4>The "Diamond Problem" in Multiple Inheritance</h4>
#
# <p><strong>Definition:</strong></p>
#     <ul>
#         <li>The "diamond problem" is a term used in object-oriented programming to describe an ambiguity that arises when a class inherits from two classes that have a common ancestor.</li>
#         <li>It occurs in languages that support multiple inheritance, where a class can inherit from more than one parent class.</li>
#         <li>The problem is named "diamond" because of the shape of the inheritance diagram.</li>
#     </ul>
#
# <p><strong>Scenario:</strong></p>
#     <ul>
#         <li>Consider classes A and B, both of which inherit from a common class, C.</li>
#         <li>Now, class D inherits from both A and B.</li>
#         <li>If there is a method or attribute in C that is overridden in both A and B, it creates ambiguity for class D because it inherits from both A and B.</li>
#         <li>The question arises: which overridden method or attribute should be used in class D?</li>
#     </ul>
#
# <p><strong>How Python Addresses the Diamond Problem:</strong></p>
#     <ul>
#         <li>Python uses a technique called "C3 linearization" to determine the order in which classes are considered during method resolution in multiple inheritance.</li>
#         <li>It ensures a consistent and predictable order of method resolution, avoiding ambiguity.</li>
#         <li>The order is determined based on the order of class declaration and the order in which base classes are listed in the class definition.</li>
#         <li>This order ensures that the most specific method in the hierarchy is chosen, addressing the diamond problem.</li>
#     </ul>

# %% [markdown]
# <h2>19. Discuss the concept of "is-a" and "has-a" relationships in inheritance, and provide examples of each.</h2>
# <P><b>Answer.</b></P>
#  <h4>Concepts of "Is-a" and "Has-a" Relationships in Inheritance</h4>
#
# <p><strong>"Is-a" Relationship (Inheritance):</strong></p>
#     <ul>
#         <li>An "is-a" relationship represents a hierarchy where one class is a specialized version of another class.</li>
#         <li>It is often implemented through inheritance, allowing a subclass to inherit attributes and behaviors from a superclass.</li>
#         <li>This relationship implies that the subclass "is a" type of the superclass.</li>
#     </ul>
#
# <pre>
# <code>
# class Animal:
#     def speak(self):
#         return "Generic animal sound"
#
# class Dog(Animal):
#     def bark(self):
#         return "Woof!"
#
#
# my_dog = Dog()
# print(my_dog.speak())
# print(my_dog.bark())
# </code>
#     </pre>
#
# <p><strong>"Has-a" Relationship (Composition):</strong></p>
#     <ul>
#         <li>A "has-a" relationship represents a composition where one class contains an instance of another class as one of its attributes.</li>
#         <li>It is often implemented through composition, allowing a class to have an object of another class as part of its structure.</li>
#         <li>This relationship implies that the class "has" another class as a component.</li>
#     </ul>
#
# <pre>
# <code>
# class Engine:
#     def start(self):
#         return "Engine started"
#
# class Car:
#     def __init__(self):
#         self.engine = Engine()
#
#     def drive(self):
#         return "Car is moving"
#
#
# my_car = Car()
# print(my_car.drive())
# print(my_car.engine.start())
# </code>
#     </pre>
#
# <p>In summary:</p>
#     <ul>
#         <li>"Is-a" relationship (inheritance) emphasizes specialization and hierarchy.</li>
#         <li>"Has-a" relationship (composition) emphasizes containment and building complex objects by combining simpler ones.</li>
#     </ul>

# %%
"""20. Create a Python class hierarchy for a university system. Start with a base class `Person` and create child
classes `Student` and `Professor`, each with their own attributes and methods. Provide an example of using
these classes in a university context."""

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        return f"Hi, I'm {self.name}, and I'm {self.age} years old."

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def study(self):
        return f"{self.name} is studying hard for exams."

class Professor(Person):
    def __init__(self, name, age, employee_id, department):
        super().__init__(name, age)
        self.employee_id = employee_id
        self.department = department

    def teach(self):
        return f"{self.name} is teaching a class in the {self.department} department."

# Example 
student_instance = Student(name="Alice", age=20, student_id="S12345")
professor_instance = Professor(name="Dr. Smith", age=45, employee_id="P98765", department="Computer Science")

#  printing information
print(student_instance.introduce())
print(student_instance.study())

print(professor_instance.introduce())
print(professor_instance.teach())

# %% [markdown]
# <h1><center>Encapsulation</center></h1>

# %% [markdown]
# <h3>1. Explain the concept of encapsulation in Python. What is its role in object-oriented programming?</h3>
# <p><b>Answer.</b></p>
# <p>
# Encapsulation is one of the fundamental principles of object-oriented programming (OOP) and is used to bundle data and methods that operate on the data into a single unit known as a class. In Python, a class is a blueprint for creating objects, and encapsulation helps in organizing and restricting access to the internal details of an object.</p>

# %% [markdown]
# <h3>2. Describe the key principles of encapsulation, including access control and data hiding.</h3>
# <p><b>Answer.</b></p>
# <ul>
#   <li><strong>Data Hiding:</strong> Encapsulation allows you to hide the implementation details of a class from the outside world. By marking attributes as private, you restrict direct access to them from outside the class.</li>
#
#   <li><strong>Access Control:</strong> Encapsulation provides a way to control the access to the attributes and methods of a class.</li>
# </ul>

# %%
"""3. How can you achieve encapsulation in Python classes? Provide an example."""

"""Answer
    Encapsulation can be achieved by using private and protected access modifiers to control the visibility of attributes
    and methods within a class. Private attributes or methods are typically denoted by prefixing their names with double underscores (__),
    and protected attributes or methods use a single underscore (_). """
    
# example
class Car:
    def __init__(self, make, model):
        self.__make = make          # private attribute
        self._model = model          # protected attribute
        self.__fuel_level = 0       # private attribute

    def get_make(self):
        return self.__make          # private attribute getter

    def get_model(self):
        return self._model          # protected attribute getter

    def set_fuel_level(self, fuel):
        if fuel >= 0:
            self.__fuel_level = fuel 
        else:
            print("Invalid fuel level")

    def drive(self):
        if self.__fuel_level > 0:
            print("Car is moving.")
            self.__fuel_level -= 1
        else:
            print("Out of fuel. Refill needed.")

# Example usage
my_car = Car("Toyota", "Camry")

# Accessing attributes using getters
print("Make:", my_car.get_make())    # Accessing private attribute
print("Model:", my_car.get_model())  # Accessing protected attribute

# Setting attribute using setter
my_car.set_fuel_level(10)            # Setting private attribute

# Performing actions using methods
my_car.drive()
my_car.drive()
my_car.drive()

# %% [markdown]
# <h3>4. Discuss the difference between public, private, and protected access modifiers in Python.</h3>
# <p><b>Answer.</b></p>
# <table>
#   <tr>
#     <th>Access Modifier</th>
#     <th>Description</th>
#     <th>Example</th>
#   </tr>
#
#   <tr>
#     <td>Public</td>
#     <td>Accessible from anywhere, both inside and outside the class/module.</td>
#     <td>
#       <pre>
#         class MyClass:
#             def __init__(self):
#                 self.public_attribute = 10
#       </pre>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Private</td>
#     <td>Accessible only within the class. Names are mangled to avoid accidental access from outside.</td>
#     <td>
#       <pre>
#         class MyClass:
#             def __init__(self):
#                 self.__private_attribute = 20
#       </pre>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Protected</td>
#     <td>Accessible within the class and its subclasses. Conventionally considered protected, but actual access is still possible.</td>
#     <td>
#       <pre>
#         class MyClass:
#             def __init__(self):
#                 self._protected_attribute = 30
#       </pre>
#     </td>
#   </tr>
# </table>

# %%
"""5. Create a Python class called `Person` with a private attribute `__name`. Provide methods to get and set the
name attribute."""

class person:
    
    def __init__(self, name):
        self.__name=name
        
    def get_name(self):
        return self.__name  

    def set_name(self, new_name):
        self.__name = new_name    

Person=person("Mohan Kumar")

# Getting the name using the getter method
current_name = Person.get_name()
print("Current Name:", current_name)

# Setting a new name using the setter method
Person.set_name("Amit Kumar")

# Getting the updated name
updated_name = Person.get_name()
print("Updated Name:", updated_name)

# %%
"""6. Explain the purpose of getter and setter methods in encapsulation. Provide examples."""

"""Answer.
    getter methods:
          Getter methods are used to retrieve the values of private or protected attributes.
          They provide a way for external code to access the state of an object without directly accessing its internal representation.
    setter methods:
          Setter methods are used to modify the values of private or protected attributes.
          They provide a controlled way to update the state of an object,"""
          
# example getter
class Person:
    def __init__(self, name):
        self.__name = name  # private attribute

    def get_name(self):
        return self.__name  # getter method for private attribute


person = Person("Mohan kumar")
name = person.get_name()
print("Person's Name:", name)

# exapmle setter
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # private attribute

    def set_balance(self, new_balance):
        if new_balance >= 0:
            self.__balance = new_balance  # setter method for private attribute
        else:
            print("Invalid balance")


account = BankAccount(1000)
account.set_balance(1500)  # Valid update
account.set_balance(-500)   # Invalid update, prints "Invalid balance"

# %% [markdown]
# <h3>7. What is name mangling in Python, and how does it affect encapsulation?</h3>
# <p><B>Answer.</B></p>
# <p>Name mangling is a technique used in Python to make the names of attributes in a class more difficult to access accidentally from outside the class. It involves adding a prefix to the names of attributes that are intended to be private or protected. The purpose is to avoid naming conflicts in situations where different classes might use the same name for their private attributes.</p>

# %%
"""8. Create a Python class called `BankAccount` with private attributes for the account balance (`__balance`)"""
#Creating a class named bank
class bank():
    
    #init function to take arrgunments.
    def __init__(self, account_holder_name, holder_mobile_no ,amount=0, account_no='XYZ_BANK_'):
        
        #Here i try to create a bank account number by adding a sting with the mobile number.
        account_no+=str(holder_mobile_no)
        self.__account_no=account_no 
        self.__account_holder_name=account_holder_name
        self.__holder_mobile_no=holder_mobile_no
        self.__amount=amount
           
    #Function to showing account holder details.      
    def account_holder_details(self):
        return f"Name = {self.__account_holder_name},  Mobile No. = {self.__holder_mobile_no}, Account No. = {self.__account_no}"
    
    
    #Function to add balance.
    def deposit_amount(self, Add_amount):
        # Checking if the add_amount is less than or equal to zero. 
        if Add_amount<=0:
            print("Please enter a valid amount !")
        else: 
        #Adding amount and updating balance.  
         self.__amount+=Add_amount
         return f'{self.__account_holder_name}  ${Add_amount} balance added to your account and your updated balance is ${self.__amount}.'
    
    #Function to withdraw balance.
    def withdraw(self,debit):
        # Checking if the withdrawal amount is less than to current balance.
        if self.__amount<debit:
            print("Insufficient balance")
        else: 
            #Withdrawaling amount and updating current amount.   
         self.__amount-=debit
         return f'{self.__account_holder_name}, ${debit} debited from your account and your current balance is ${self.__amount}.'
    
    #Function to check bank balance. 
    def check_balance(self):
        return f'${self.__amount}'


#Creating some account holders and passing there details.
account_holder1=bank('Monu', 6798548745)
account_holder2=bank('Sonu', 5634784589)
account_holder3=bank('Rohan', 8078324565)
account_holder4=bank('Sohan', 8709568754)
account_holder5=bank('Mohan', 6584587547)

#Adding some money to the bank account.
account_holder5.deposit_amount(6000)

# %% [markdown]
# <h3>9. Discuss the advantages of encapsulation in terms of code maintainability and security.</h3>
# <p><b>Answer.</b></p>
# <table>
#   <tr>
#     <th>Advantage</th>
#     <th>Description</th>
#   </tr>
#
#   <tr>
#     <td><strong>Code Maintainability</strong></td>
#     <td>
#       <p>Encapsulation promotes modularity by grouping related data and behavior within a class. This makes it easier to understand, maintain, and update code.</p>
#       <p>Changes to the internal implementation of a class do not affect the external code as long as the public interface remains unchanged. This isolation simplifies updates and enhancements.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Data Hiding</strong></td>
#     <td>
#       <p>By hiding the internal implementation details through private or protected access modifiers, encapsulation shields the complexity of the class from external code.</p>
#       <p>This reduces the risk of unintended interference, enhances readability, and allows for changes in the internal representation without affecting external code.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Access Control</strong></td>
#     <td>
#       <p>Encapsulation allows for fine-grained control over access to attributes and methods. Public, private, and protected access modifiers define the visibility of class members.</p>
#       <p>This control prevents external code from directly modifying or accessing sensitive data, reducing the potential for errors and ensuring adherence to the class's intended usage.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Code Security</strong></td>
#     <td>
#       <p>Encapsulation contributes to code security by restricting access to sensitive information. Private attributes and methods are not directly accessible from outside the class.</p>
#       <p>While not providing absolute security, encapsulation discourages unauthorized access and modification, reducing the risk of unintended data corruption or misuse.</p>
#     </td>
#   </tr>
# </table>

# %%
"""10. How can you access private attributes in Python? Provide an example demonstrating the use of name
mangling."""

"""Answer
        
In Python, private attributes are typically indicated by using a double underscore (__) as a prefix.
While direct access to private attributes from outside the class is discouraged to maintain encapsulation,
it is still technically possible through a process called name mangling.

Name mangling involves modifying the name of a private attribute by adding the class name as a prefix.
This makes it more challenging to access the attribute accidentally. """

# example
class MyClass:
    def __init__(self):
        self.__private_attribute = 42

# Creating an instance of the class
obj = MyClass()

# Attempting to access private attribute directly (not recommended)
# This will raise an AttributeError due to name mangling.
# Access should be done through getter methods.
try:
    print(obj.__private_attribute)
except AttributeError as e:
    print(f"AttributeError: {e}")

# Accessing private attribute using name mangling
# This is discouraged and not recommended in practice.
# It's shown here for illustration purposes.
mangled_name = f"_{obj.__class__.__name__}__private_attribute"



value = getattr(obj, mangled_name, None)

# Displaying the value obtained through name mangling
print("Value obtained through name mangling:", value)

# %%
"""11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses,
and implement encapsulation principles to protect sensitive information."""

class Person:
    def __init__(self, name, age):
        self._name = name  # protected attribute
        self._age = age    # protected attribute

    def get_name(self):
        return self._name

    def set_name(self, new_name):
        self._name = new_name

    def get_age(self):
        return self._age

    def set_age(self, new_age):
        if 0 <= new_age <= 150:  # Assuming a reasonable age range
            self._age = new_age
        else:
            print("Invalid age")

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.__student_id = student_id  # private attribute

    def get_student_id(self):
        return self.__student_id

    def set_student_id(self, new_student_id):
        self.__student_id = new_student_id

class Teacher(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.__employee_id = employee_id  # private attribute

    def get_employee_id(self):
        return self.__employee_id

    def set_employee_id(self, new_employee_id):
        self.__employee_id = new_employee_id

class Course:
    def __init__(self, course_code, course_name):
        self._course_code = course_code  # protected attribute
        self._course_name = course_name  # protected attribute
        self.__students_enrolled = []    # private attribute

    def get_course_code(self):
        return self._course_code

    def set_course_code(self, new_course_code):
        self._course_code = new_course_code

    def get_course_name(self):
        return self._course_name

    def set_course_name(self, new_course_name):
        self._course_name = new_course_name

    def enroll_student(self, student):
        self.__students_enrolled.append(student)

    def get_enrolled_students(self):
        return self.__students_enrolled

# Example usage
student1 = Student("Aman", 18, "S123")
teacher1 = Teacher("Mr. Amit", 35, "T456")
course1 = Course("CS101", "Introduction to Computer Science")

course1.enroll_student(student1)
course1.enroll_student(Student("Ankur", 19, "S456"))

print(f"Course: {course1.get_course_code()} - {course1.get_course_name()}")
print("Enrolled Students:")
for student in course1.get_enrolled_students():
    print(f"  {student.get_name()} (ID: {student.get_student_id()})")

print(f"Teacher: {teacher1.get_name()} (ID: {teacher1.get_employee_id()})")
print(f"Student: {student1.get_name()} (ID: {student1.get_student_id()})")

# %%
"""12. Explain the concept of property decorators in Python and how they relate to encapsulation."""

"""Answer
In Python, property decorators are a way to implement getter, setter, and deleter methods for class attributes.
They provide a convenient syntax for accessing and modifying the values of attributes 
while allowing the developer to control the behavior of these operations."""

class MyClass:
    def __init__(self):
        self._value = 0  # protected attribute

    @property
    def value(self):
        return self._value  # getter method

    @value.setter
    def value(self, new_value):
        if new_value >= 0:
            self._value = new_value  # setter method
        else:
            print("Invalid value")

    @value.deleter
    def value(self):
        print("Deleting value")
        del self._value  # deleter method

# Example usage
obj = MyClass()

# Accessing value using the property
current_value = obj.value
print("Current Value:", current_value)

# Setting value using the property
obj.value = 42

# Deleting value using the property
del obj.value

# %%
"""13. What is data hiding, and why is it important in encapsulation? Provide examples."""

"""Answer
        
Data hiding is a concept in object-oriented programming (OOP) that involves restricting access to the internal details of an object.
In the context of encapsulation, data hiding is achieved by making the implementation details,
such as attributes and methods, private or protected, meaning they are not directly accessible from outside the class."""

class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # private attribute

    def get_balance(self):
        return self.__balance  # getter method for private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount

# Example usage
account = BankAccount(1000)

# Accessing balance using the getter method
current_balance = account.get_balance()
print("Current Balance:", current_balance)

# Depositing and withdrawing funds
account.deposit(500)
account.withdraw(200)

# Attempting direct access to the private attribute (not recommended)
# This will raise an AttributeError due to data hiding.
try:
    print(account.__balance)
except AttributeError as e:
    print(f"AttributeError: {e}")

# %%
"""14. Create a Python class called `Employee` with private attributes for salary (`__salary`) and employee ID (`__employee_id`). Provide a method to calculate yearly bonuses."""

#Creating a class named Employee.
class Employee():
    
    # init function to take argunments.
    def __init__(self, employee_id, employes_name ,employee_salary):
        self.__employee_id=employee_id
        self.__employes_name=employes_name
        self.__employee_salary=employee_salary
    
    #Function to show employees details.
    def emmployee_details(self):
        return f'Employee ID = {self.__employee_id}, Name = {self.__employes_name}, Salary = {self.__employee_salary} INR'
    


#Adding some employee details. 
employee1=Employee(5156,'Aman',350000) 
employee2=Employee(5465,'Vijay',450000)
employee3=Employee(5162,'Ram',300000)
employee4=Employee(8752,'Monu',250000)
employee5=Employee(7623,'Sumit',1200000)

#Printing employee details with 10% of yearly bonus.
print(employee5.emmployee_details())

# %% [markdown]
# <h3>15. Discuss the use of accessors and mutators in encapsulation. How do they help maintain control over
# attribute access?</h3>
# <p><b>Answer.</b></p>
#
# <p>
#   Encapsulation in object-oriented programming involves bundling data and methods that operate on the data within a single unit, typically a class. Accessors and mutators are key components of encapsulation, playing a crucial role in controlling access to the attributes of a class.
# </p>
#
# <ul>
#   <li><strong>Accessors:</strong> Accessors, commonly known as getter methods, provide controlled read-only access to the private or protected attributes of a class. They retrieve the current value of an attribute without allowing direct modification. Accessors ensure that external code can inquire about the state of an object while maintaining control over the data.</li>
#
#   <li><strong>Mutators:</strong> Mutators, commonly known as setter methods, offer controlled write access to the private or protected attributes of a class. They allow external code to modify the value of an attribute, but often with validations or constraints. Mutators help enforce rules and maintain the integrity of the class's state during attribute modifications.</li>
# </ul>

# %% [markdown]
# <h3>16. What are the potential drawbacks or disadvantages of using encapsulation in Python?</h3>
# <P><b>Answer.</b></P>
# <table>
#   <tr>
#     <th>Drawback</th>
#     <th>Description</th>
#   </tr>
#
#   <tr>
#     <td><strong>Increased Complexity:</strong></td>
#     <td>
#       <p>Encapsulation, if applied excessively, can lead to increased complexity in the code. The use of accessors and mutators may result in more method calls, making the code harder to understand and maintain.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Performance Overhead:</strong></td>
#     <td>
#       <p>The use of getter and setter methods introduces a level of indirection that can result in a slight performance overhead compared to direct attribute access. This can be a concern in performance-critical applications.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Verbosity:</strong></td>
#     <td>
#       <p>Encapsulation, particularly when strictly followed, can lead to more verbose code. The need to create getter and setter methods for each attribute may increase the overall size of the codebase.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Less Flexibility:</strong></td>
#     <td>
#       <p>Strict encapsulation may limit the flexibility of external code. For example, if an attribute is made private, it cannot be accessed directly, even if there might be cases where direct access would be appropriate.</p>
#     </td>
#   </tr>
# </table>

# %%
"""17. Create a Python class for a library system that encapsulates book information, including titles, authors,
and availability status."""

class Book:
    def __init__(self, title, author, availability=True):
        self.__title = title            # private attribute
        self.__author = author          # private attribute
        self.__availability = availability  # private attribute

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

    def is_available(self):
        return self.__availability

    def borrow_book(self):
        if self.__availability:
            print(f"The book '{self.__title}' by {self.__author} has been borrowed.")
            self.__availability = False
        else:
            print(f"The book '{self.__title}' is currently not available.")

    def return_book(self):
        if not self.__availability:
            print(f"The book '{self.__title}' has been returned.")
            self.__availability = True
        else:
            print(f"The book '{self.__title}' is already available.")

# Example usage
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald")
book2 = Book("To Kill a Mockingbird", "Harper Lee")

# Displaying book information
print("Book Information:")
print(f"Title: {book1.get_title()}, Author: {book1.get_author()}, Available: {book1.is_available()}")
print(f"Title: {book2.get_title()}, Author: {book2.get_author()}, Available: {book2.is_available()}")

# Borrowing and returning books
book1.borrow_book()
book2.borrow_book()

book1.return_book()
book2.return_book()

# Displaying updated book availability
print("\nUpdated Book Availability:")
print(f"Title: {book1.get_title()}, Available: {book1.is_available()}")
print(f"Title: {book2.get_title()}, Available: {book2.is_available()}")

# %% [markdown]
# <h3>18. Explain how encapsulation enhances code reusability and modularity in Python programs.</h3>
# <P><b>Answer.</b></P>
# <table>
#   <tr>
#     <th>Aspect</th>
#     <th>Explanation</th>
#   </tr>
#
#   <tr>
#     <td><strong>Code Reusability</strong></td>
#     <td>
#       <p>Encapsulation promotes code reusability by encapsulating related data and behavior within a class. The encapsulated class can be easily reused in different parts of the program or even in different projects.</p>
#       <p>External code interacts with the class through its public interface, relying on well-defined methods and attributes. As a result, the internal implementation details are hidden, allowing the class to be reused without concern for its internal workings.</p>
#     </td>
#   </tr>
#
#   <tr>
#     <td><strong>Modularity</strong></td>
#     <td>
#       <p>Encapsulation contributes to modularity by creating self-contained units of code. Each class encapsulates its own data and behavior, forming a modular and independent component within the overall program structure.</p>
#       <p>Modular design enables easier maintenance and updates. Changes to the internal implementation of a class do not affect other parts of the program, reducing the risk of unintended consequences and making the codebase more manageable.</p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <h3>19. Describe the concept of information hiding in encapsulation. Why is it essential in software development?</h3>
# <p><b>Answer.</b></p>
# <p>
#   In software development, the concept of <strong>information hiding</strong> is an integral aspect of encapsulation. Information hiding involves the deliberate concealment of implementation details within a class, exposing only a well-defined public interface to external code. This is achieved through the use of access modifiers like private and protected, restricting direct access to certain attributes or methods.
# </p>
#
# <ul>
#   <li><strong>Enhanced Security:</strong> Information hiding contributes to enhanced security by preventing unauthorized access to sensitive data and implementation details. Private attributes or methods can only be accessed or modified through controlled interfaces, reducing the risk of data misuse or corruption.</li>
#
#   <li><strong>Reduced Complexity:</strong> By hiding the internal workings of a class, information hiding reduces the complexity of external code. Developers interact with the public interface, focusing on the essential functionalities without being burdened by intricate implementation details.</li>
#
#   <li><strong>Improved Maintainability:</strong> Concealing implementation details allows for better maintainability. Changes to the internal structure of a class, such as modifying attributes or methods, do not impact external code as long as the public interface remains unchanged. This isolation simplifies updates and enhancements.</li>
#
#   <li><strong>Facilitates Evolution:</strong> Information hiding facilitates the evolution of software systems. Developers can evolve the internal implementation of a class without affecting the overall functionality. This separation allows for the introduction of new features or improvements without disrupting existing code.</li>
# </ul>

# %%
"""20. Create a Python class called `Customer` with private attributes for customer details like name, address,
and contact information. Implement encapsulation to ensure data integrity and security."""

class Customer:
    def __init__(self, name, address, contact_info):
        self.__name = name            # private attribute
        self.__address = address      # private attribute
        self.__contact_info = contact_info  # private attribute

    def get_name(self):
        return self.__name

    def set_name(self, new_name):
        # Add any validation logic if needed
        self.__name = new_name

    def get_address(self):
        return self.__address

    def set_address(self, new_address):
        # Add any validation logic if needed
        self.__address = new_address

    def get_contact_info(self):
        return self.__contact_info

    def set_contact_info(self, new_contact_info):
        # Add any validation logic if needed
        self.__contact_info = new_contact_info

# Example usage
customer1 = Customer("Amit Kumar", "123 Main St", "amitkumar@example.com")

# Accessing customer details using getter methods
print("Customer Details:")
print("Name:", customer1.get_name())
print("Address:", customer1.get_address())
print("Contact Info:", customer1.get_contact_info())

# Modifying customer details using setter methods
customer1.set_name("Jay")
customer1.set_address("456 Oak Ave")
customer1.set_contact_info("jay@example.com")

# Displaying updated customer details
print("\nUpdated Customer Details:")
print("Name:", customer1.get_name())
print("Address:", customer1.get_address())
print("Contact Info:", customer1.get_contact_info())

# %% [markdown]
# <h1><center>Polymorphism</center></h1>

# %% [markdown]
# <h3>1. What is polymorphism in Python? Explain how it is related to object-oriented programming.</h3>
# <p><b>Answer.</b></p>
# <p>
#     Polymorphism is a key concept in object-oriented programming (OOP) that allows objects of different types to be treated as objects of a common type. It enables a single interface to be used for a general class of actions, making code more flexible and reusable.
# </p>
#
# <p>
#     <strong>Compile-time Polymorphism (Static Binding):</strong>
#     <br>
#     This is also known as method overloading. It occurs when two or more methods in the same class have the same name but different parameters. The method that gets called is determined at compile-time based on the number and types of arguments.
# </p>
#
# <p>
#     <strong>Run-time Polymorphism (Dynamic Binding):</strong>
#     <br>
#     This is achieved through method overriding, where a method in a base class is redefined in a derived class. The decision of which method to call is made at runtime based on the actual type of the object.
# </p>
#
# <ul>
#     <li>
#         Polymorphism allows objects of different types to be treated as objects of a common type.
#     </li>
#     <li>
#         Compile-time Polymorphism, or method overloading, is determined at compile-time based on the number and types of arguments.
#     </li>
#     <li>
#         Run-time Polymorphism, or method overriding, makes the decision of which method to call at runtime based on the actual type of the object.
#     </li>
#     <li>
#         These concepts contribute to code flexibility, reusability, and a more generic approach in OOP.
#     </li>
# </ul>

# %% [markdown]
# <h3>2. Describe the difference between compile-time polymorphism and runtime polymorphism in Python.</h3>
# <p><b>Answer.</b></p>
# <table border="1">
#     <thead>
#         <tr>
#             <th>Aspect</th>
#             <th>Compile-time Polymorphism (Static Binding)</th>
#             <th>Runtime Polymorphism (Dynamic Binding)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Description</td>
#             <td colspan="2">Polymorphism allows objects of different types to be treated as objects of a common type.</td>
#         </tr>
#         <tr>
#             <td>Type</td>
#             <td>Method Overloading</td>
#             <td>Method Overriding</td>
#         </tr>
#         <tr>
#             <td>Decision Time</td>
#             <td>Compile-time</td>
#             <td>Runtime</td>
#         </tr>
#         <tr>
#             <td>Other Names</td>
#             <td>Static Binding</td>
#             <td>Dynamic Binding</td>
#         </tr>
#         <tr>
#             <td>Implementation</td>
#             <td>
#                 Occurs when two or more methods in the same class have the same name but different parameters.
#                 The method that gets called is determined at compile-time based on the number and types of arguments.
#             </td>
#             <td>
#                 Achieved through method overriding, where a method in a base class is redefined in a derived class.
#                 The decision of which method to call is made at runtime based on the actual type of the object.
#             </td>
#         </tr>
#     </tbody>
# </table>

# %%
"""3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism
through a common method, such as `calculate_area()`."""

import math

# Base class for shapes
class Shape:
    def calculate_area(self):
        pass

# Circle class inheriting from Shape
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2

# Square class inheriting from Shape
class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length**2

# Triangle class inheriting from Shape
class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        return 0.5 * self.base * self.height

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area of the shape: {shape.calculate_area()}")

# Creating instances of different shapes
circle = Circle(radius=5)
square = Square(side_length=4)
triangle = Triangle(base=6, height=3)

# Demonstrate polymorphism by calling the common method
print_area(circle)   
print_area(square)    
print_area(triangle)

# %%
"""4. Explain the concept of method overriding in polymorphism. Provide an example."""

"""Answer
    Method overriding is a concept in polymorphism where a subclass provides a specific implementation for a method that is already defined in its superclass.
    In other words, the subclass provides its own version of a method that is already present in its parent class. """
    
class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

# Creating instances of the subclasses
dog = Dog()
cat = Cat()

# Demonstrating method overriding
print(dog.speak())  
print(cat.speak())

# %%
"""5. How is polymorphism different from method overloading in Python? Provide examples for both."""

"""Answer.
    Polymorphism is a concept in object-oriented programming that allows objects of different types to be treated as objects of a common type.
    While Method overloading refers to defining multiple methods in the same class with the same name but different parameters. """
    
# Polymorphism
class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

# Creating instances of the subclasses
dog = Dog()
cat = Cat()

# Demonstrating polymorphism
print(dog.speak())  
print(cat.speak())  

# Method Overloading
class MathOperations:
    def add(self, a, b, c=None):
        if c is not None:
            return a + b + c
        else:
            return a + b

# Creating an instance of the class
math_ops = MathOperations()

# Demonstrating method overloading
result1 = math_ops.add(2, 3)        
result2 = math_ops.add(2, 3, 4)    

print(result1)  
print(result2)

# %%
"""6. Create a Python class called `Animal` with a method `speak()`. Then, create child classes like `Dog`, `Cat`, and `Bird`, each with their own `speak()` method. Demonstrate polymorphism by calling the `speak()` method
on objects of different subclasses."""

class Animal:
    def speak(self):
        return "Generic animal sound"

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

class Bird(Animal):
    def speak(self):
        return "Tweet!"

# Creating instances of the subclasses
dog = Dog()
cat = Cat()
bird = Bird()

# Demonstrating polymorphism
print(dog.speak())  
print(cat.speak())  
print(bird.speak())

# %%
"""7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example
using the `abc` module."""

"""Answer.
    The abc module in Python provides the ABC (Abstract Base Class) meta-class and decorators to define abstract classes and abstract methods.
    Abstract methods are declared in the abstract class but do not provide an implementation."""
    
from abc import ABC, abstractmethod

# Abstract class with abstract method
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

# Concrete subclass Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius**2

# Concrete subclass Square
class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length**2

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area of the shape: {shape.calculate_area()}")

# Creating instances of the concrete subclasses
circle = Circle(radius=5)
square = Square(side_length=4)

# Demonstrating polymorphism by calling the common method
print_area(circle)  
print_area(square)

# %%
"""8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic `start()` method that prints a message specific to each vehicle type."""
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def start(self):
        return "Generic vehicle starting"

# Car class inheriting from Vehicle
class Car(Vehicle):
    def __init__(self, brand, model, fuel_type):
        super().__init__(brand, model)
        self.fuel_type = fuel_type

    def start(self):
        return f"{self.brand} {self.model} (Car) with {self.fuel_type} fuel is starting"

# Bicycle class inheriting from Vehicle
class Bicycle(Vehicle):
    def __init__(self, brand, model, num_gears):
        super().__init__(brand, model)
        self.num_gears = num_gears

    def start(self):
        return f"{self.brand} {self.model} (Bicycle) with {self.num_gears} gears is starting"

# Boat class inheriting from Vehicle
class Boat(Vehicle):
    def __init__(self, brand, model, propulsion_type):
        super().__init__(brand, model)
        self.propulsion_type = propulsion_type

    def start(self):
        return f"{self.brand} {self.model} (Boat) with {self.propulsion_type} propulsion is starting"

# Function to demonstrate polymorphism
def start_vehicle(vehicle):
    print(vehicle.start())

# Creating instances of different vehicle types
car = Car(brand="Toyota", model="Camry", fuel_type="Petrol")
bicycle = Bicycle(brand="Trek", model="Mountain Bike", num_gears=21)
boat = Boat(brand="Sea Ray", model="Sundancer", propulsion_type="Outboard")

# Demonstrating polymorphism by calling the common method
start_vehicle(car)      
start_vehicle(bicycle) 
start_vehicle(boat)

# %% [markdown]
# <h3>9. Explain the significance of the `isinstance()` and `issubclass()` functions in Python polymorphism.</h3>
# <p><b>Answer.</b></p>
# <ul>
#     <li>
#         <strong>isinstance() Function:</strong>
#         <p>
#             The <code>isinstance()</code> function in Python is used to determine whether an object is an instance of a particular class or a tuple of classes. This function is significant in polymorphism as it allows developers to check the type of an object dynamically. This is useful when you need to perform specific operations based on the type of an object, promoting flexibility in code that interacts with different types within a common interface.
#         </p>
#     </li>
#     <li>
#         <strong>issubclass() Function:</strong>
#         <p>
#             The <code>issubclass()</code> function is employed to check whether a class is a subclass of another class. In the context of polymorphism, this function is crucial for verifying class relationships. It allows developers to ensure that a particular class is derived from a specific base class, ensuring adherence to a common interface. This is essential for maintaining consistency and predictability when working with objects of different types within a polymorphic system.
#         </p>
#     </li>
# </ul>

# %%
"""10. What is the role of the `@abstractmethod` decorator in achieving polymorphism in Python? Provide an
example."""

"""Answer.
        The @abstractmethod decorator is used in Python to define abstract methods within abstract classes.
        An abstract method is a method declared in an abstract class without providing an implementation.
        Subclasses are then required to provide a concrete implementation for these abstract methods."""

from abc import ABC, abstractmethod

# Abstract class with abstract method
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

# Concrete subclass Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius**2

# Concrete subclass Square
class Square(Shape):
    def __init__(self, side_length):
        self.side_length = side_length

    def calculate_area(self):
        return self.side_length**2

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area of the shape: {shape.calculate_area()}")

# Creating instances of the concrete subclasses
circle = Circle(radius=5)
square = Square(side_length=4)

# Demonstrating polymorphism by calling the common method
print_area(circle)  
print_area(square)

# %%
"""11. Create a Python class called `Shape` with a polymorphic method `area()` that calculates the area of different shapes (e.g., circle, rectangle, triangle)."""

import math

class Shape:
    def area(self):
        pass

# Circle class inheriting from Shape
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

# Rectangle class inheriting from Shape
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Triangle class inheriting from Shape
class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

# Function to demonstrate polymorphism
def print_area(shape):
    print(f"Area of the shape: {shape.area()}")

# Creating instances of different shape types
circle = Circle(radius=5)
rectangle = Rectangle(length=4, width=6)
triangle = Triangle(base=3, height=8)

# Demonstrating polymorphism by calling the common method
print_area(circle)     
print_area(rectangle) 
print_area(triangle)

# %% [markdown]
# <h3>12. Discuss the benefits of polymorphism in terms of code reusability and flexibility in Python programs.</h3>
# <p><b>Answer.</b></p>
# <p>
#     <strong>Polymorphism in Python:</strong> Polymorphism is a fundamental concept in object-oriented programming that allows objects of different types to be treated as objects of a common type. This concept significantly contributes to the code reusability and flexibility of Python programs.
# </p>
#
# <ul>
#     <li>
#         <p>
#             <strong>Code Reusability:</strong> Polymorphism enables the creation of a common interface for a class hierarchy, allowing different classes to implement the same methods with their specific behaviors. This promotes code reusability by avoiding redundant code and providing a consistent way to interact with objects of different types.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Flexibility:</strong> With polymorphism, a program can be designed to work with objects of a common base class without needing to know the specific subclass types. This enhances flexibility as new subclasses can be added later without modifying the existing code. The ability to treat different objects uniformly simplifies code maintenance and extensions.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Interface Consistency:</strong> Polymorphism ensures that different classes adhere to a common interface, providing a standardized set of methods. This consistency simplifies the usage of objects in various parts of the program, making it easier to understand and predict the behavior of different classes.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Dynamic Behavior:</strong> The dynamic nature of polymorphism allows method calls to be resolved at runtime. This provides the flexibility to override and customize behavior in derived classes, contributing to more adaptable and extensible code.
#         </p>
#     </li>
# </ul>

# %% [markdown]
# <h3>13. Explain the use of the `super()` function in Python polymorphism. How does it help call methods of parent
# classes?</h3>
# <p><b>Answer.</b></p>
# <p>
#     <strong>Using the <code>super()</code> Function in Python Polymorphism:</strong> The <code>super()</code> function is a built-in Python function that is particularly useful in the context of polymorphism to call methods of parent classes. It provides a way to invoke a method in the superclass, allowing a subclass to extend or override the behavior defined in the parent class.
# </p>
#
# <ul>
#     <li>
#         <p>
#             <strong>Calling Parent Class Methods:</strong> In polymorphic scenarios, when a method is overridden in a subclass, the <code>super()</code> function is used to call the method of the parent class. This enables the subclass to leverage and extend the functionality of the parent class method while incorporating its own specific behavior.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Passing Arguments:</strong> The <code>super()</code> function is particularly helpful when the overridden method in the subclass requires the same set of arguments as the method in the parent class. It ensures that the method is called with the appropriate arguments, promoting consistency in the code.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Method Resolution Order (MRO):</strong> The <code>super()</code> function is aware of the method resolution order (MRO) in the inheritance hierarchy. It dynamically determines the next class in the MRO, allowing for correct method invocation and preventing potential conflicts in multiple inheritance scenarios.
#         </p>
#     </li>
# </ul>
#
# <p>
#     In summary, the <code>super()</code> function is a valuable tool in Python polymorphism, facilitating the calling of methods from parent classes in a way that promotes code reuse and flexibility within class hierarchies.
# </p>

# %%
"""14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking, credit card) and demonstrate polymorphism by implementing a common `withdraw()` method."""

class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            return f"Withdrawal of ${amount} successful. New balance: ${self.balance}"
        else:
            return "Invalid withdrawal amount or insufficient funds."

# SavingsAccount class inheriting from BankAccount
class SavingsAccount(BankAccount):
    def __init__(self, account_number, balance, interest_rate):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def withdraw(self, amount):
        # Additional logic for savings account (e.g., check withdrawal limits)
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            return f"Savings withdrawal of ${amount} successful. New balance: ${self.balance}"
        else:
            return "Invalid withdrawal amount or insufficient funds for savings account."

# CheckingAccount class inheriting from BankAccount
class CheckingAccount(BankAccount):
    def __init__(self, account_number, balance, overdraft_limit):
        super().__init__(account_number, balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        # Additional logic for checking account (e.g., consider overdraft limit)
        if amount > 0 and amount <= (self.balance + self.overdraft_limit):
            self.balance -= amount
            return f"Checking withdrawal of ${amount} successful. New balance: ${self.balance}"
        else:
            return "Invalid withdrawal amount or insufficient funds for checking account."

# CreditCardAccount class inheriting from BankAccount
class CreditCardAccount(BankAccount):
    def __init__(self, account_number, balance, credit_limit):
        super().__init__(account_number, balance)
        self.credit_limit = credit_limit

    def withdraw(self, amount):
        # Additional logic for credit card account (e.g., consider credit limit)
        if amount > 0 and amount <= (self.balance + self.credit_limit):
            self.balance -= amount
            return f"Credit card withdrawal of ${amount} successful. New balance: ${self.balance}"
        else:
            return "Invalid withdrawal amount or exceeding credit limit for credit card account."

# Function to demonstrate polymorphism
def perform_withdrawal(account, amount):
    print(account.withdraw(amount))

# Creating instances of different account types
savings_account = SavingsAccount(account_number="SA123", balance=1000, interest_rate=0.02)
checking_account = CheckingAccount(account_number="CA456", balance=1500, overdraft_limit=500)
credit_card_account = CreditCardAccount(account_number="CC789", balance=-200, credit_limit=1000)

# Demonstrating polymorphism by calling the common method
perform_withdrawal(savings_account, 200)         
perform_withdrawal(checking_account, 1800)     
perform_withdrawal(credit_card_account, 1200)

# %%
"""15. Describe the concept of operator overloading in Python and how it relates to polymorphism. Provide
examples using operators like `+` and `*`."""

"""Answer.
    
Operator overloading in Python refers to the ability to define and customize the behavior of operators for user-defined classes.
It allows you to define how an object of a class should behave when used with standard operators."""

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other_point):
        # Overloading the + operator for Point objects
        return Point(self.x + other_point.x, self.y + other_point.y)

# Creating instances of the Point class
point1 = Point(1, 2)
point2 = Point(3, 4)

# Using the overloaded + operator
result_point = point1 + point2
print(f"Resultant Point: ({result_point.x}, {result_point.y})")

# %% [markdown]
# <h3>16. What is dynamic polymorphism, and how is it achieved in Python?</h3>
# <p><b>Answer.</b></p>
# <p>
#     <strong>Dynamic Polymorphism in Python:</strong> Dynamic polymorphism, also known as runtime polymorphism, is a concept in object-oriented programming where the actual method or operation to be executed is determined at runtime. This allows objects of different types to be treated as objects of a common type, and the appropriate method is chosen based on the actual type of the object during program execution.
# </p>
#
# <p>
#     In Python, dynamic polymorphism is achieved through method overriding. When a subclass provides a specific implementation for a method that is already defined in its superclass, the decision of which method to call is made at runtime based on the actual type of the object.
# </p>
#
# <ul>
#     <li>
#         <p>
#             <strong>Method Overriding:</strong> In Python, dynamic polymorphism is commonly achieved through method overriding. Subclasses provide their own implementation for a method that is already defined in the superclass. When an object is of the subclass type, calling the overridden method results in the execution of the specific implementation provided by the subclass.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Common Interface:</strong> Dynamic polymorphism allows objects of different types to be treated uniformly through a common interface. This promotes flexibility in code, as the same method can be called on objects of different classes, and the appropriate implementation is determined dynamically at runtime.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Runtime Decision:</strong> The decision of which method to call is deferred until runtime, enabling a more adaptable and extensible code structure. This dynamic resolution of method calls enhances the ability to work with diverse objects within a common hierarchy.
#         </p>
#     </li>
# </ul>

# %%
"""17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement polymorphism through a common `calculate_salary()` method."""

class Employee:
    def __init__(self, employee_id, name, role):
        self.employee_id = employee_id
        self.name = name
        self.role = role

    def calculate_salary(self):
        # Default implementation for calculating salary (can be overridden by subclasses)
        return 0

# Manager class inheriting from Employee
class Manager(Employee):
    def __init__(self, employee_id, name, team_size):
        super().__init__(employee_id, name, role="Manager")
        self.team_size = team_size

    def calculate_salary(self):
        # Manager-specific salary calculation (example: base salary + bonus based on team size)
        base_salary = 50000
        bonus_per_member = 2000
        return base_salary + (self.team_size * bonus_per_member)

# Developer class inheriting from Employee
class Developer(Employee):
    def __init__(self, employee_id, name, programming_language):
        super().__init__(employee_id, name, role="Developer")
        self.programming_language = programming_language

    def calculate_salary(self):
        # Developer-specific salary calculation (example: base salary + language-specific bonus)
        base_salary = 60000
        language_bonus = {"Python": 5000, "JavaScript": 4500, "Java": 4000}
        bonus = language_bonus.get(self.programming_language, 0)
        return base_salary + bonus

# Designer class inheriting from Employee
class Designer(Employee):
    def __init__(self, employee_id, name, design_tool):
        super().__init__(employee_id, name, role="Designer")
        self.design_tool = design_tool

    def calculate_salary(self):
        # Designer-specific salary calculation (example: base salary + tool-specific bonus)
        base_salary = 55000
        tool_bonus = {"Photoshop": 3000, "Sketch": 2500, "Figma": 2000}
        bonus = tool_bonus.get(self.design_tool, 0)
        return base_salary + bonus

# Function to demonstrate polymorphism
def print_employee_salary(employee):
    print(f"{employee.role} {employee.name}'s Salary: ${employee.calculate_salary()}")

# Creating instances of different employee types
manager = Manager(employee_id=1, name="John Smith", team_size=8)
developer = Developer(employee_id=2, name="Alice Johnson", programming_language="Python")
designer = Designer(employee_id=3, name="Chris Brown", design_tool="Sketch")

# Demonstrating polymorphism by calling the common method
print_employee_salary(manager)    
print_employee_salary(developer) 
print_employee_salary(designer)

# %% [markdown]
# <h3>18. Discuss the concept of function pointers and how they can be used to achieve polymorphism in Python.</h3>
# <p><b>Answer.</b></p>
# <p>
#     <strong>Function Pointers and Polymorphism in Python:</strong> While Python does not have explicit function pointers like some other languages, the concept of function pointers is closely related to the ability to pass functions as arguments to other functions, as well as using function attributes. In Python, this functionality is often leveraged to achieve a form of polymorphism.
# </p>
#
# <p>
#     In Python, polymorphism is more commonly achieved through duck typing and dynamic dispatch. While the concept of function pointers is not as explicit as in languages like C, the ability to pass functions dynamically provides a flexible way to implement polymorphic behavior.
# </p>
#
# <ul>
#     <li>
#         <p>
#             <strong>Function Passing:</strong> In Python, functions are first-class citizens, meaning they can be passed as arguments to other functions. This allows the creation of functions that can operate on different types of objects, achieving a form of polymorphism.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Dynamic Dispatch:</strong> Python relies on dynamic dispatch to determine the appropriate method or function to call at runtime. This dynamic nature allows different objects to respond to the same method or function call, promoting polymorphic behavior without explicit function pointers.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Attributes as Functions:</strong> In Python, objects can have attributes that are callable, effectively acting as function pointers. This allows for the creation of classes with attributes that can be used to achieve polymorphism by dynamically changing the behavior of objects.
#         </p>
#     </li>
# </ul>
#
# <p>
#     While Python's approach to polymorphism is more implicit compared to languages with explicit function pointers, the language's flexibility and dynamic nature provide powerful ways to achieve polymorphic behavior through function passing and dynamic dispatch.
# </p>

# %% [markdown]
# <h3>19. Explain the role of interfaces and abstract classes in polymorphism, drawing comparisons between them.</h3>
#
# <p><b>Answer.</b></p>
# <p>
#     <strong>Role of Interfaces and Abstract Classes in Polymorphism:</strong> Interfaces and abstract classes are both essential concepts in object-oriented programming that play a crucial role in achieving polymorphism by defining a common interface for classes. While they share similarities, there are key differences between them in terms of structure and usage.
# </p>
#
# <ul>
#     <li>
#         <p>
#             <strong>Interfaces:</strong> An interface in OOP defines a contract specifying a set of methods that a class must implement. It serves as a blueprint for what methods a class should have, without providing any implementation details. Interfaces enable the definition of a common set of behaviors that multiple classes can share, promoting a consistent interface for polymorphic behavior. In Python, interfaces are represented informally, and a class is considered to implement an interface if it provides the specified methods.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Abstract Classes:</strong> An abstract class is a class that cannot be instantiated on its own and may contain abstract methods—methods without a concrete implementation. Abstract classes serve as a partial implementation, providing some common functionality while leaving certain methods to be implemented by concrete subclasses. In Python, abstract classes can be defined using the `abc` module, and the `@abstractmethod` decorator is used to declare abstract methods. Abstract classes can be used to define a common structure for polymorphism while allowing for partial implementation in the base class.
#         </p>
#     </li>
#     <li>
#         <p>
#             <strong>Comparisons:</strong>
#             <ul>
#                 <li>
#                     <p><strong>Implementation:</strong> Interfaces provide a contract without any implementation, while abstract classes can provide both abstract and concrete methods.</p>
#                 </li>
#                 <li>
#                     <p><strong>Instantiation:</strong> Abstract classes cannot be instantiated directly, but interfaces do not have instances and are implemented by classes.</p>
#                 </li>
#                 <li>
#                     <p><strong>Multiple Inheritance:</strong> Multiple interfaces can be implemented by a class, promoting flexibility. Abstract classes support single inheritance, limiting the reuse of common functionality.</p>
#                 </li>
#             </ul>
#         </p>
#     </li>
# </ul>
#
# <p>
#     In summary, both interfaces and abstract classes contribute to polymorphism by providing a common structure for classes. Interfaces focus on defining a contract, while abstract classes allow for a combination of common implementation and partial implementation in subclasses.
# </p>

# %%
"""20. Create a Python class for a zoo simulation, demonstrating polymorphism with different animal types (e.g., mammals, birds, reptiles) and their behavior (e.g., eating, sleeping, making sounds)."""

# Base class representing an Animal
class Animal:
    def __init__(self, name):
        self.name = name

    def make_sound(self):
        pass  # Abstract method for making a sound

    def eat(self):
        print(f"{self.name} is eating.")

    def sleep(self):
        print(f"{self.name} is sleeping.")

# Mammal class inheriting from Animal
class Mammal(Animal):
    def __init__(self, name, fur_color):
        super().__init__(name)
        self.fur_color = fur_color

    def make_sound(self):
        print(f"{self.name} the mammal makes a generic mammal sound.")

    def run(self):
        print(f"{self.name} the mammal is running.")

# Bird class inheriting from Animal
class Bird(Animal):
    def __init__(self, name, feather_color):
        super().__init__(name)
        self.feather_color = feather_color

    def make_sound(self):
        print(f"{self.name} the bird chirps.")

    def fly(self):
        print(f"{self.name} the bird is flying.")

# Reptile class inheriting from Animal
class Reptile(Animal):
    def __init__(self, name, scales_color):
        super().__init__(name)
        self.scales_color = scales_color

    def make_sound(self):
        print(f"{self.name} the reptile hisses.")

    def crawl(self):
        print(f"{self.name} the reptile is crawling.")

# Function to demonstrate polymorphism
def perform_animal_activities(animal):
    print(f"\nActivities of {animal.name}:")
    animal.make_sound()
    animal.eat()
    animal.sleep()
    if isinstance(animal, Mammal):
        animal.run()
    elif isinstance(animal, Bird):
        animal.fly()
    elif isinstance(animal, Reptile):
        animal.crawl()

# Creating instances of different animal types
lion = Mammal(name="Leo", fur_color="golden")
parrot = Bird(name="Polly", feather_color="green")
snake = Reptile(name="Sly", scales_color="brown")

# Demonstrating polymorphism by calling the common methods
perform_animal_activities(lion)
perform_animal_activities(parrot)
perform_animal_activities(snake)

# %% [markdown]
# <h1><center>Abstraction</center></h1>

# %% [markdown]
# <h3>1. What is abstraction in Python, and how does it relate to object-oriented programming?</h3>
# <p><b>Answer.</b></p>
# <p>Abstraction in Python, as well as in object-oriented programming (OOP) in general, refers to the concept of simplifying complex systems by modeling classes based on the essential properties and behaviors they possess, while hiding unnecessary details. It involves focusing on the relevant aspects of an object and ignoring the irrelevant ones.</p>

# %% [markdown]
# <h3>2. Describe the benefits of abstraction in terms of code organization and complexity reduction.</h3>
# <p><b>Answer.</b></p>
# <h4>Benefits of Abstraction in Code Organization and Complexity Reduction</h4>
#
# <p>
#         Abstraction in programming, especially in object-oriented paradigms like Python, offers several advantages in terms of code organization and complexity reduction.
#     </p>
#
# <h4>1. Modularity and Encapsulation</h4>
#     <p>
#         Abstraction allows code to be organized into modular units, such as classes and objects. Each module encapsulates a specific set of functionalities, making it easier to understand and maintain. This promotes the principle of encapsulation, where the internal details of a module are hidden from the outside, reducing complexity and preventing unintended interference.
#     </p>
#
# <h4>2. Reusability</h4>
#     <p>
#         By creating abstract classes that define common interfaces, abstraction encourages the reuse of code. Concrete classes can inherit from these abstract classes, inheriting their methods and properties. This promotes the "Don't Repeat Yourself" (DRY) principle, as developers can reuse and extend existing code rather than duplicating it.
#     </p>
#
# <h4>3. Hierarchical Structure</h4>
#     <p>
#         Abstraction facilitates the creation of a hierarchical structure in code. Abstract classes can serve as high-level blueprints, providing a common foundation for multiple related classes. This hierarchical organization enhances code readability and makes it easier to conceptualize complex systems by breaking them down into manageable levels of abstraction.
#     </p>
#
# <h4>4. Maintenance and Scalability</h4>
#     <p>
#         Abstracting away complex implementations into higher-level constructs makes maintenance more straightforward. When changes are required, developers can focus on the relevant abstraction level without delving into unnecessary details. Additionally, abstraction supports scalability, as new functionality can be added by extending existing abstract classes or creating new ones without disrupting the overall structure.
#     </p>
#
# <h4>5. Collaboration and Team Development</h4>
#     <p>
#         Abstraction fosters collaboration among team members. By defining clear interfaces in abstract classes, different team members can work on distinct components without interfering with each other's work. This separation of concerns enhances team productivity and allows for parallel development on different parts of a project.
#     </p>
#
# <p>
#         In conclusion, the use of abstraction in programming contributes significantly to code organization and complexity reduction, promoting modularity, reusability, hierarchical structure, ease of maintenance, scalability, and effective collaboration in team development.
#     </p>

# %%
"""3. Create a Python class called `Shape` with an abstract method `calculate_area()`. Then, create child classes (e.g., `Circle`, `Rectangle`) that implement the `calculate_area()` method. Provide an example of
using these classes."""

from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# Example usage
circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Circle Area:", circle.calculate_area())
print("Rectangle Area:", rectangle.calculate_area())

# %%
"""4. Explain the concept of abstract classes in Python and how they are defined using the `abc` module. Provide
an example."""

"""Answer
    The abc module in Python provides the ABC (Abstract Base Class) and abstractmethod decorators,
    which can be used to define abstract classes and methods, respectively."""
    
# Example
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def display_info(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2

    def display_info(self):
        print(f"Circle with radius {self.radius}")

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def display_info(self):
        print(f"Rectangle with length {self.length} and width {self.width}")

# Example usage
circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Circle Area:", circle.calculate_area())
circle.display_info()

print("Rectangle Area:", rectangle.calculate_area())
rectangle.display_info()

# %% [markdown]
# <h3>5. How do abstract classes differ from regular classes in Python? Discuss their use cases.</h3>
# <p><b>Answer.</b></p>
#  <h3>Abstract Classes vs. Regular Classes in Python</h3>
#
# <p>
#         In Python, abstract classes and regular classes serve different purposes, and their use cases revolve around design principles and code organization.
#     </p>
#
# <h4>Abstract Classes</h4>
#     <p>
#         <strong>Definition:</strong> Abstract classes are classes that cannot be instantiated on their own and may contain one or more abstract methods, which are methods without a concrete implementation in the abstract class.
#     </p>
#     <p>
#         <strong>Use Cases:</strong>
#     </p>
#     <ul>
#         <li>**Defining Interfaces:** Abstract classes are often used to define interfaces that enforce a common set of methods that concrete subclasses must implement. This ensures a consistent interface across related classes.</li>
#         <li>**Code Blueprint:** Abstract classes serve as blueprints for creating related classes. They provide a common structure and help in organizing code by specifying a set of methods that must be present in concrete subclasses.</li>
#         <li>**Forcing Implementation:** Abstract classes can be used to force concrete subclasses to provide implementations for specific methods, ensuring that essential functionalities are not overlooked.</li>
#     </ul>
#
# <h4>Regular Classes</h4>
#     <p>
#         <strong>Definition:</strong> Regular classes, also known as concrete classes, can be instantiated on their own and may or may not inherit from other classes. They typically provide concrete implementations for all their methods.
#     </p>
#     <p>
#         <strong>Use Cases:</strong>
#     </p>
#     <ul>
#         <li>**Creating Instances:** Regular classes are instantiated to create objects that can be used in the application. They provide the actual implementation of methods and represent tangible entities or concepts in the program.</li>
#         <li>**Code Organization:** Regular classes contribute to the overall structure of the program by encapsulating data and behavior. They are essential for organizing and modeling the various components of the system.</li>
#         <li>**Inheritance:** Regular classes can inherit from other regular classes or abstract classes. They can extend functionality through inheritance and provide additional methods or override existing ones.</li>
#     </ul>
#
# <p>
#         In summary, abstract classes are used to define interfaces and blueprints for related classes, ensuring a common structure and behavior, while regular classes represent concrete entities and contribute to the actual implementation of the program.
#     </p>

# %%
"""6. Create a Python class for a bank account and demonstrate abstraction by hiding the account balance and
providing methods to deposit and withdraw funds."""

class BankAccount:
    def __init__(self, account_holder, initial_balance=0.0):
        self._account_holder = account_holder  # _account_holder is a convention to indicate it's intended to be protected
        self._balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Deposited ${amount}. New balance: ${self._balance}")
        else:
            print("Invalid deposit amount. Please deposit a positive amount.")

    def withdraw(self, amount):
        if amount > 0 and amount <= self._balance:
            self._balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self._balance}")
        elif amount <= 0:
            print("Invalid withdrawal amount. Please withdraw a positive amount.")
        else:
            print("Insufficient funds for withdrawal.")

    def get_balance(self):
        return self._balance

    def get_account_holder(self):
        return self._account_holder

# Example usage
account1 = BankAccount("John Doe", 1000.0)

print(f"Account holder: {account1.get_account_holder()}")
print(f"Initial balance: ${account1.get_balance()}")

account1.deposit(500.0)
account1.withdraw(200.0)
account1.withdraw(800.0)  

print(f"Final balance: ${account1.get_balance()}")

# %% [markdown]
# <h3>7. Discuss the concept of interface classes in Python and their role in achieving abstraction.</h3>
# <p><b>Answer.</b></p>
#   <h4>Interface Classes in Python and Their Role in Achieving Abstraction</h4>
#
# <p>Python is an object-oriented programming language that supports the concept of abstraction through various mechanisms. One important mechanism is the use of interface classes, which play a crucial role in achieving abstraction.</p>
#
# <h4>Abstraction in Python</h4>
#
# <p>Abstraction is the process of hiding the complex implementation details of an object and exposing only the essential features. It allows developers to focus on what an object does rather than how it achieves its functionality. Python achieves abstraction through classes and interfaces.</p>
#
# <h4>Interface Classes</h4>
#
# <p>In Python, an interface is a collection of abstract methods. An abstract method is a method that is declared in an interface but does not have an implementation. Interface classes provide a blueprint for other classes to follow, ensuring that certain methods are implemented without specifying how they should be implemented.</p>
#
# <p>Unlike some other programming languages, Python does not have a specific <code>interface</code> keyword. Instead, developers use abstract base classes (ABCs) from the <code>abc</code> module to create interfaces. The <code>ABC</code> class is used as a metaclass for defining abstract classes and methods.</p>
#
# <h4>Role in Achieving Abstraction</h4>
#
#  <p>Interface classes play a crucial role in achieving abstraction by:</p>
#
# <ul>
#     <li><strong>Defining a Contract:</strong> Interface classes define a contract that concrete classes must adhere to. The contract specifies the methods that concrete classes must implement, ensuring a common interface.</li>
#
# <li><strong>Enforcing Method Implementation:</strong> By declaring abstract methods in interfaces, Python enforces that concrete classes provide implementations for these methods. This ensures that objects of different classes can be used interchangeably as they share a common interface.</li>
#
# <li><strong>Promoting Code Reusability:</strong> Interfaces allow developers to create reusable components. Concrete classes that implement the same interface can be used interchangeably, promoting code reusability and making the code more maintainable.</li>
#  </ul>
#
# <p>Here's an example of defining an interface using the <code>ABC</code> class:</p>
#
# <pre>
#         <code>
# from abc import ABC, abstractmethod
#
# class MyInterface(ABC):
#
#     @abstractmethod
#     def my_method(self):
#         pass
#      </code>
# </pre>
#
# <p>Any class that wants to implement the <code>MyInterface</code> interface must provide an implementation for the <code>my_method</code> abstract method.</p>
#
#  <p>In conclusion, interface classes in Python, implemented using abstract base classes, play a key role in achieving abstraction. They define a contract, enforce method implementation, and promote code reusability, contributing to the overall design and structure of object-oriented Python programs.</p>

# %%
"""8. Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., `eat()`, `sleep()`) in an abstract base class."""
from abc import ABC, abstractmethod

class Animal(ABC):
    def __init__(self, name):
        self.name = name

    @abstractmethod
    def eat(self):
        pass

    @abstractmethod
    def sleep(self):
        pass

class Mammal(Animal):
    def __init__(self, name):
        super().__init__(name)

    def give_birth(self):
        print(f"{self.name} is giving birth.")

    # Implementation of abstract methods
    def eat(self):
        print(f"{self.name} is eating.")

    def sleep(self):
        print(f"{self.name} is sleeping.")

class Bird(Animal):
    def __init__(self, name):
        super().__init__(name)

    def lay_eggs(self):
        print(f"{self.name} is laying eggs.")

    # Implementation of abstract methods
    def eat(self):
        print(f"{self.name} is pecking at seeds.")

    def sleep(self):
        print(f"{self.name} is roosting for the night.")

class Fish(Animal):
    def __init__(self, name):
        super().__init__(name)

    def swim(self):
        print(f"{self.name} is swimming.")

    # Implementation of abstract methods
    def eat(self):
        print(f"{self.name} is feeding on plankton.")

    def sleep(self):
        print(f"{self.name} is resting underwater.")

# Example usage
if __name__ == "__main__":
    lion = Mammal("Lion")
    sparrow = Bird("Sparrow")
    goldfish = Fish("Goldfish")

    lion.give_birth()
    lion.eat()
    lion.sleep()

    sparrow.lay_eggs()
    sparrow.eat()
    sparrow.sleep()

    goldfish.swim()
    goldfish.eat()
    goldfish.sleep()

# %%
"""9. Explain the significance of encapsulation in achieving abstraction. Provide examples."""
"""Answer
        Encapsulation is a fundamental concept in object-oriented programming that involves bundling data (attributes or properties) and
        the methods (functions or procedures) that operate on that data within a single unit called a class.
        The key idea is to hide the internal details of an object and only expose what is necessary for the outside world, 
        promoting information hiding and abstraction."""
        
class BankAccount:
    def __init__(self, balance):
        self._balance = balance  # Protected attribute

    def get_balance(self):
        return self._balance

    def deposit(self, amount):
        self._balance += amount

    def withdraw(self, amount):
        if amount <= self._balance:
            self._balance -= amount
        else:
            print("Insufficient funds")
bank_balancee=BankAccount(5000)

print(bank_balancee.get_balance())

# %% [markdown]
# <h3>10. What is the purpose of abstract methods, and how do they enforce abstraction in Python classes?</h3>
# <p><b>Answer.</b></p>
# <h4>Purpose of Abstract Methods and Enforcing Abstraction in Python Classes</h4>
#
# <p>Abstract methods in Python classes serve the purpose of defining a method signature without providing its implementation. They play a crucial role in enforcing abstraction by ensuring that concrete subclasses provide their own implementation for these methods.</p>
#
# <h4>Purpose of Abstract Methods</h4>
#
# <p>The main purposes of abstract methods are:</p>
#
# <ul>
#  <li><strong>Defining a Blueprint:</strong> Abstract methods define a blueprint or contract for derived classes. They specify which methods must be implemented by any concrete subclass, creating a common interface for those classes.</li>
#
#  <li><strong>Forcing Implementation:</strong> Abstract methods do not have a default implementation in the abstract base class. Subclasses are required to provide their own implementation, ensuring that each class adheres to the specified contract.</li>
#
# <li><strong>Promoting Consistency:</strong> Abstract methods promote consistency across a class hierarchy. They ensure that related classes share a common set of methods, making the code more predictable and maintainable.</li>
# </ul>
# <h4>Enforcing Abstraction in Python Classes</h4>
#
# <p>In Python, abstraction is achieved through abstract base classes (ABCs) provided by the <code>abc</code> module. The <code>ABC</code> class is used as a metaclass for defining abstract methods. An abstract class can have concrete methods as well, but it must have at least one abstract method.</p>
#
# <p>Here's an example demonstrating the use of abstract methods:</p>
#
# <pre>
#         <code>
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#
#     @abstractmethod
#     def area(self):
#         pass
#
# class Circle(Shape):
#
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return 3.14 * self.radius ** 2
#         </code>
#     </pre>
#
# <p>In this example, the <code>Shape</code> class defines an abstract method <code>area()</code>. The concrete subclass <code>Circle</code> must provide its implementation for the <code>area()</code> method. Attempting to instantiate an object of the abstract class <code>Shape</code> directly will result in an error, enforcing the abstraction.</p>

# %%
"""11. Create a Python class for a vehicle system and demonstrate abstraction by defining common methods (e.g., `start()`, `stop()`) in an abstract base class."""

from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        self.engine_status = 'off'

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

    def get_info(self):
        return f"{self.brand} {self.model}"

class Car(Vehicle):
    def __init__(self, brand, model, num_doors):
        super().__init__(brand, model)
        self.num_doors = num_doors

    def start(self):
        if self.engine_status == 'off':
            print(f"{self.get_info()} engine started.")
            self.engine_status = 'on'
        else:
            print(f"{self.get_info()} engine is already running.")

    def stop(self):
        if self.engine_status == 'on':
            print(f"{self.get_info()} engine stopped.")
            self.engine_status = 'off'
        else:
            print(f"{self.get_info()} engine is already off.")

class Motorcycle(Vehicle):
    def __init__(self, brand, model, num_wheels):
        super().__init__(brand, model)
        self.num_wheels = num_wheels

    def start(self):
        if self.engine_status == 'off':
            print(f"{self.get_info()} engine started.")
            self.engine_status = 'on'
        else:
            print(f"{self.get_info()} engine is already running.")

    def stop(self):
        if self.engine_status == 'on':
            print(f"{self.get_info()} engine stopped.")
            self.engine_status = 'off'
        else:
            print(f"{self.get_info()} engine is already off.")

# Example usage
if __name__ == "__main__":
    car = Car("Toyota", "Camry", 4)
    motorcycle = Motorcycle("Harley-Davidson", "Sportster", 2)

    car.start()
    car.stop()

    motorcycle.start()
    motorcycle.stop()

# %% [markdown]
# <h3>12. Describe the use of abstract properties in Python and how they can be employed in abstract classes.</h3>
# <p><b>Answer.</b></p>
# <h4>Abstract Properties in Python and Their Use in Abstract Classes</h4>
#
# <p>In Python, abstract properties are used to define attributes (properties) in abstract base classes without specifying their implementation. Abstract properties ensure that concrete subclasses provide their own implementations for these attributes, enforcing a common interface across the class hierarchy.</p>
#
# <h4>Use of Abstract Properties</h4>
#
# <p>The use of abstract properties is demonstrated through the <code>abc</code> module in Python. The <code>ABC</code> (Abstract Base Class) class serves as a metaclass for defining abstract properties using the <code>@property</code> decorator.</p>
#
# <p>Here's an example:</p>
#
# <pre>
#         <code>
# from abc import ABC, abstractmethod, abstractproperty
#
# class Shape(ABC):
#
#     @abstractproperty
#     def area(self):
#         pass
#
# class Circle(Shape):
#
#     def __init__(self, radius):
#         self._radius = radius
#
#     @property
#     def area(self):
#         return 3.14 * self._radius ** 2
#         </code>
#     </pre>
#
# <p>In this example, the <code>Shape</code> class defines an abstract property <code>area</code>. The concrete subclass <code>Circle</code> must provide its implementation for the <code>area</code> property using the <code>@property</code> decorator. Attempting to instantiate an object of the abstract class <code>Shape</code> directly will result in an error, enforcing the abstraction.</p>
#
# <h4>Use in Abstract Classes</h4>
#
# <p>Abstract properties are often employed in abstract classes to define attributes that should be implemented by subclasses. These properties act as placeholders, guiding the structure of derived classes without specifying the actual data.</p>
#
# <pre>
#         <code>
# class Animal(ABC):
#
#     @abstractproperty
#     def sound(self):
#         pass
#
# class Dog(Animal):
#
#     def __init__(self, name):
#         self.name = name
#
#     @property
#     def sound(self):
#         return "Woof!"
#
# class Cat(Animal):
#
#     def __init__(self, name):
#         self.name = name
#
#     @property
#     def sound(self):
#         return "Meow!"
#         </code>
#     </pre>
#
# <p>In this example, the <code>Animal</code> abstract class defines an abstract property <code>sound</code>. The concrete subclasses <code>Dog</code> and <code>Cat</code> provide their own implementations for the <code>sound</code> property, ensuring that each animal type has its distinctive sound.</p>

# %%
"""13. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement abstraction by defining a common `get_salary()` method."""

from abc import ABC, abstractmethod

class company(ABC):
    
    def __init__(self, salary,employe):
        self.salary=salary
        self.employe=employe
    
    @abstractmethod
    def get_salary(self):
        pass
    
class manager(company):
        
    def __init__(self, salary, employe):
        super().__init__(salary, employe)  
       
    def get_salary(self):
        return f"Manager {self.employe} \nSalary {self.salary}"    
    
class developer(company):
        
    def __init__(self, salary, employe):
        super().__init__(salary, employe)  
        
    def get_salary(self):
        return f"Developer {self.employe} \nSalary {self.salary}"  

class designer(company):
        
    def __init__(self, salary, employe):
        super().__init__(salary, employe)  
        
    def get_salary(self):
        return f"Designer {self.employe} \nSalary {self.salary}"         
    

if __name__=="__main__":
    
    Employee_manager=manager(70000, "Aman") 
    Employee_developer=developer(50000, "Amit")
    Employee_designer=designer(45000 , "sumit") 
    
    print(Employee_manager.get_salary())
    print(Employee_developer.get_salary())
    print(Employee_designer.get_salary())

# %% [markdown]
# <h3>14. Discuss the differences between abstract classes and concrete classes in Python, including their
# instantiation.</h3>
# <p><b>Answer.</b></p>
# <h4>Differences between Abstract Classes and Concrete Classes in Python</h4>
#
# <p>Abstract classes and concrete classes are two types of classes in Python that serve different purposes in object-oriented programming. Here are the key differences between them:</p>
#
# <table border="1" cellspacing="0" cellpadding="8">
#         <tr>
#             <th>Feature</th>
#             <th>Abstract Classes</th>
#             <th>Concrete Classes</th>
#         </tr>
#         <tr>
#             <td><strong>Definition</strong></td>
#             <td>Abstract classes are classes that cannot be instantiated on their own. They may contain abstract methods that must be implemented by their concrete subclasses.</td>
#             <td>Concrete classes are classes that can be instantiated directly. They provide complete implementations for all methods, including inherited abstract methods.</td>
#         </tr>
#         <tr>
#             <td><strong>Instantiation</strong></td>
#             <td>Cannot be instantiated directly. They are meant to be subclassed, and their abstract methods must be implemented in the derived classes.</td>
#             <td>Can be instantiated directly using the constructor. Objects of concrete classes have complete implementations for all methods.</td>
#         </tr>
#         <tr>
#             <td><strong>Abstract Methods</strong></td>
#             <td>May contain abstract methods that do not have an implementation in the abstract class itself. Subclasses must provide implementations for these methods.</td>
#             <td>Does not have abstract methods. All methods in a concrete class have complete implementations.</td>
#         </tr>
# <tr>
#             <td><strong>Use Case</strong></td>
#             <td>Used when you want to define a common interface for a group of related classes, leaving some methods to be implemented by subclasses.</td>
#             <td>Used when you have a complete implementation for all methods, and you want to create instances of the class directly.</td>
# </tr>
# </table>

# %% [markdown]
# <h3>15. Explain the concept of abstract data types (ADTs) and their role in achieving abstraction in Python.</h3>
# <p><b>Answer.</b></p>
#   <h4>Abstract Data Types (ADTs) in Python and Their Role in Achieving Abstraction</h4>
#
# <p>Abstract Data Types (ADTs) are a high-level conceptual model for data structures that define a set of operations without specifying the underlying implementation. ADTs play a crucial role in achieving abstraction in Python, allowing developers to focus on the functionality and behavior of data structures without being concerned with their internal details.</p>
#
# <h4>Key Concepts of ADTs:</h4>
#
#  <ul>
#     <li><strong>Encapsulation:</strong> ADTs encapsulate data and operations into a single unit. The internal details of the data structure are hidden, and only the essential methods are exposed.</li>
#
#  <li><strong>Abstraction:</strong> ADTs provide a level of abstraction by defining a set of operations without specifying how these operations are implemented. This allows for a clear separation between the interface and the implementation.</li>
#
# <li><strong>Modularity:</strong> ADTs promote modularity by organizing data and operations into independent modules. This modular structure enhances code organization, readability, and maintainability.</li>
#
# <li><strong>Reusability:</strong> ADTs facilitate code reuse by allowing developers to use the same abstract interface for different implementations. This promotes the development of generic algorithms that can work with various data structures.</li>
# </ul>
#
# <h4>Role in Achieving Abstraction:</h4>
#
# <p>ADTs serve as blueprints for creating concrete data structures in Python. By defining a set of abstract operations and properties, ADTs allow developers to create consistent and interchangeable components. The use of ADTs abstracts away the complexities of the underlying data structure, promoting a clear and intuitive interface for working with data.</p>
#
# <p>Common examples of ADTs in Python include lists, queues, stacks, and dictionaries. These abstract interfaces provide a standard set of methods and behaviors, allowing developers to interact with the data structures without being concerned about the specific implementation details.</p>

# %%
"""16. Create a Python class for a computer system, demonstrating abstraction by defining common methods (e.g., `power_on()`, `shutdown()`) in an abstract base class."""

from abc import ABC, abstractmethod

class ComputerSystem(ABC):
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        self.power_status = 'off'

    @abstractmethod
    def power_on(self):
        pass

    @abstractmethod
    def shutdown(self):
        pass

    def get_info(self):
        return f"{self.brand} {self.model}"

class DesktopComputer(ComputerSystem):
    def __init__(self, brand, model):
        super().__init__(brand, model)

    def power_on(self):
        if self.power_status == 'off':
            print(f"{self.get_info()} is powering on.")
            self.power_status = 'on'
        else:
            print(f"{self.get_info()} is already powered on.")

    def shutdown(self):
        if self.power_status == 'on':
            print(f"{self.get_info()} is shutting down.")
            self.power_status = 'off'
        else:
            print(f"{self.get_info()} is already powered off.")

class Laptop(ComputerSystem):
    def __init__(self, brand, model):
        super().__init__(brand, model)

    def power_on(self):
        if self.power_status == 'off':
            print(f"{self.get_info()} is booting up.")
            self.power_status = 'on'
        else:
            print(f"{self.get_info()} is already powered on.")

    def shutdown(self):
        if self.power_status == 'on':
            print(f"{self.get_info()} is shutting down gracefully.")
            self.power_status = 'off'
        else:
            print(f"{self.get_info()} is already powered off.")

# Example usage
if __name__ == "__main__":
    desktop = DesktopComputer("Dell", "OptiPlex")
    laptop = Laptop("HP", "EliteBook")

    desktop.power_on()
    desktop.shutdown()

    laptop.power_on()
    laptop.shutdown()

# %% [markdown]
# <h3>17. Discuss the benefits of using abstraction in large-scale software development projects.</h3>
# <p><b>Answer.</b></p>
#  <h4>Benefits of Abstraction in Large-Scale Software Development Projects</h4>
#
# <p>Abstraction is a fundamental concept in software development that involves hiding complex implementation details and exposing only essential features. In large-scale software development projects, the use of abstraction brings numerous benefits, contributing to the efficiency, maintainability, and overall success of the project.</p>
#
# <h4>1. Modular Code Organization:</h4>
#    <p>Abstraction allows developers to organize code into modular components with clear interfaces. Each module, abstracted from the others, can be developed and maintained independently, making the codebase more manageable and scalable.</p>
#
#    <h4>2. Code Reusability:</h4>
#  <p>Abstracting common functionalities into reusable components promotes code reusability. Developers can utilize existing abstract interfaces and classes in different parts of the project, reducing redundancy and saving development time.</p>
#
#  <h4>3. Ease of Maintenance:</h4>
#     <p>Abstraction makes it easier to maintain large-scale projects by providing a clear separation between the interface and implementation. Updates or changes to the internal details of a module can be made without affecting the external code that relies on its abstract interface.</p>
#
#    <h4>4. Scalability:</h4>
#     <p>Large-scale projects often involve continuous growth and expansion. Abstraction allows for scalable development, where new features and modules can be added without disrupting the existing codebase. This facilitates project growth and adaptability to changing requirements.</p>
#
#  <h4>5. Collaboration and Team Productivity:</h4>
#     <p>Abstraction promotes collaboration among team members by defining clear interfaces that facilitate communication. Teams can work on different modules concurrently, each focusing on their assigned abstract components, leading to increased productivity and parallel development.</p>
#
#    <h4>6. Reduced Complexity:</h4>
#     <p>By abstracting complex implementation details, abstraction helps in reducing the overall complexity of the codebase. Developers can interact with high-level abstractions, understanding and working with the system without being overwhelmed by intricate internal workings.</p>
#
#    <h4>7. Enhanced Testability:</h4>
#     <p>Abstracting components allows for easier testing of individual modules in isolation. Unit testing becomes more straightforward, as developers can focus on testing the functionality exposed through abstract interfaces without being concerned about the internal intricacies.</p>
#
#    <h4>8. Improved Code Readability:</h4>
#     <p>Abstraction contributes to improved code readability by providing a higher-level view of the software architecture. Developers can understand and work with abstracted components without delving into unnecessary implementation details, making the code more comprehensible.</p>
#
#    <p>Overall, the benefits of abstraction in large-scale software development projects extend beyond individual modules to positively impact collaboration, scalability, and maintainability, ultimately contributing to the success of the entire project.</p>

# %%
"""19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class."""

from abc import ABC, abstractmethod

class LibrarySystem(ABC):
    def __init__(self, library_name):
        self.library_name = library_name
        self.books = []

    @abstractmethod
    def add_book(self, book_title, author):
        pass

    @abstractmethod
    def borrow_book(self, book_title):
        pass

    @abstractmethod
    def return_book(self, book_title):
        pass

    def display_books(self):
        if not self.books:
            print("No books available in the library.")
        else:
            print("Books available in the library:")
            for book in self.books:
                print(f"- {book['title']} by {book['author']}")

class PublicLibrary(LibrarySystem):
    def add_book(self, book_title, author):
        new_book = {'title': book_title, 'author': author}
        self.books.append(new_book)
        print(f"Book '{book_title}' by {author} added to the library.")

    def borrow_book(self, book_title):
        for book in self.books:
            if book['title'] == book_title:
                self.books.remove(book)
                print(f"Book '{book_title}' borrowed successfully.")
                return True
        print(f"Book '{book_title}' not found in the library.")
        return False

    def return_book(self, book_title):
        returned_book = {'title': book_title, 'author': 'Unknown'}
        self.books.append(returned_book)
        print(f"Book '{book_title}' returned to the library.")

class SchoolLibrary(LibrarySystem):
    def add_book(self, book_title, author, subject):
        new_book = {'title': book_title, 'author': author, 'subject': subject}
        self.books.append(new_book)
        print(f"Book '{book_title}' by {author} added to the school library for '{subject}'.")

    def borrow_book(self, book_title):
        for book in self.books:
            if book['title'] == book_title:
                self.books.remove(book)
                print(f"Book '{book_title}' borrowed from the school library.")
                return True
        print(f"Book '{book_title}' not found in the school library.")
        return False

    def return_book(self, book_title):
        returned_book = {'title': book_title, 'author': 'Unknown', 'subject': 'Unknown'}
        self.books.append(returned_book)
        print(f"Book '{book_title}' returned to the school library.")

# Example usage
if __name__ == "__main__":
    public_library = PublicLibrary("City Public Library")
    school_library = SchoolLibrary("XYZ School Library")

    public_library.add_book("The Great Gatsby", "F. Scott Fitzgerald")
    public_library.add_book("To Kill a Mockingbird", "Harper Lee")
    

    school_library.add_book("Introduction to Python", "John Doe", "Computer Science")
    school_library.add_book("Chemistry Essentials", "Jane Smith", "Chemistry")

    public_library.display_books()

# %% [markdown]
# <h3>20. Describe the concept of method abstraction in Python and how it relates to polymorphism.</h3>
# <p><b>Answer.</b></p>
#  <h4>Method Abstraction in Python and its Relation to Polymorphism</h4>
#
# <p>Method abstraction in Python refers to the practice of defining methods in a way that emphasizes the interface or behavior without exposing the implementation details. It allows developers to interact with objects through a common set of method signatures, promoting code clarity, reusability, and adaptability. Method abstraction is closely related to polymorphism, a concept that enables objects to take on multiple forms through a shared interface.</p>
#
# <h4>Method Abstraction:</h4>
#
# <p>In Python, method abstraction is often achieved through the use of abstract classes and abstract methods. Abstract methods declare a method signature without providing the implementation in the abstract class. Concrete subclasses are then required to provide their own implementations for these abstract methods, ensuring a consistent interface across the class hierarchy.</p>
#
# <pre>
#         <code>
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#
#     @abstractmethod
#     def calculate_area(self):
#         pass
#
# class Circle(Shape):
#
#     def __init__(self, radius):
#         self.radius = radius
#
#     def calculate_area(self):
#         return 3.14 * self.radius ** 2
#         </code>
#     </pre>
#
#  <p>In this example, the abstract class <code>Shape</code> defines an abstract method <code>calculate_area</code>. The concrete subclass <code>Circle</code> must provide its own implementation for <code>calculate_area</code>. This abstraction allows different shapes to implement the same interface while providing unique behavior.</p>
#
# <h4>Polymorphism:</h4>
#
# <p>Polymorphism, meaning "many forms," allows objects to be treated as instances of their parent class, providing a common interface for diverse subclasses. In Python, polymorphism is achieved through method overriding, where a subclass provides its own implementation for a method defined in its superclass.</p>
#
# <pre>
#         <code>
# class Animal:
#
#     def make_sound(self):
#         pass
#
# class Dog(Animal):
#
#     def make_sound(self):
#         return "Woof!"
#
# class Cat(Animal):
#
#     def make_sound(self):
#         return "Meow!"
#         </code>
#     </pre>
#
# <p>In this example, both <code>Dog</code> and <code>Cat</code> are subclasses of <code>Animal</code>. They override the <code>make_sound</code> method, allowing instances of <code>Dog</code> and <code>Cat</code> to be used interchangeably where an <code>Animal</code> is expected.</p>
#
# <h4>Relation between Method Abstraction and Polymorphism:</h4>
#
# <p>Method abstraction and polymorphism are closely related concepts. Abstraction allows developers to define a common interface through abstract methods, while polymorphism enables objects to exhibit different behaviors through method overriding. Together, they contribute to code flexibility, extensibility, and the ability to work with diverse objects in a unified manner.</p>

# %% [markdown]
# <h1><center>Composition</center></h1>
